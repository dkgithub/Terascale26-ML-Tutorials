# %% [markdown]
# # Tutorial 1: Polynomial Regression & Bias-Variance Tradeoff
#
# **Author:** ML Tutorial Series
# **Target Audience:** PhD students and early career postdocs
# **Duration:** 90-120 minutes
#
# ---
#
# ## Overview
#
# This tutorial introduces the fundamentals of PyTorch and machine learning through **polynomial regression**, demonstrating the critical **bias-variance tradeoff**.
#
# ### Learning Objectives
#
# By the end of this tutorial, you will:
#
# - Understand PyTorch tensor operations and automatic differentiation
# - Learn to create custom model classes using `nn.Module`
# - Implement forward passes and parameter optimization for arbitrary polynomial orders
# - Grasp the training loop structure and parameter evolution
# - **Visualize and understand the bias-variance tradeoff**
# - Recognize underfitting (high bias) and overfitting (high variance)
# - Learn when model complexity matches data complexity
# - Understand feature normalization for numerical stability
#
# ### Key Concepts
#
# - **Underfitting (High Bias):** Model too simple to capture the true function
# - **Good Fit (Balanced):** Model complexity matches data complexity
# - **Overfitting (High Variance):** Model too complex, fits noise instead of signal
# - **Feature Normalization:** Critical for numerical stability with high-order polynomials

# %% [markdown]
# ---
#
# ## Part 1: Setup and Imports
#
# Let's start by importing all necessary libraries and configuring our logging system.

# %%
# Standard library imports
import torch
import matplotlib.pyplot as plt
import numpy as np
import logging

# Tutorial imports
from polynomial_tutorial.LinearRegressor import LinearRegressor, PolynomialRegressor
from polynomial_tutorial.train import train_model, evaluate_model
from polynomial_tutorial.utils import FeatureNormalizer
from polynomial_tutorial.logger import configure_logging

# Configure logging
configure_logging()
logger = logging.getLogger(__name__)

# Set matplotlib style
plt.style.use('default')
# %matplotlib inline

print("✓ All imports successful!")
print(f"PyTorch version: {torch.__version__}")
print(f"Device: {'CUDA' if torch.cuda.is_available() else 'CPU'}")
# Out:
# ✓ All imports successful!
# PyTorch version: 2.10.0+cu128
# Device: CPU

# %% [markdown]
# ---
#
# ## Part 2: Configuration
#
# ### Experiment Configuration
#
# The bias-variance tradeoff depends on the relationship between:
# - **Data polynomial order:** Complexity of the true underlying function
# - **Regressor polynomial order:** Complexity of the model we fit
#
# **Three scenarios:**
# 1. `regressor_order < data_order` → **Underfitting** (high bias)
# 2. `regressor_order = data_order` → **Good fit** (balanced)
# 3. `regressor_order > data_order` → **Overfitting** (high variance)

# %%
# ============================================================================
# CONFIGURATION: Experiment with these parameters!
# ============================================================================

# TRUE DATA GENERATION
data_poly_order = 4  # Order of the TRUE underlying function
coeffs_true = [1.5, 0.4, 0.07, -0.02, 0.0005]  # True coefficients [a₀, a₁, a₂, a₃]

# MODEL CONFIGURATION  
regressor_poly_order = 50  # Order of the MODEL to fit

# TRAINING CONFIGURATION
n_samples = 50
noise_std = 5  #0.5
num_epochs = 50000
learning_rate = 0.001

# FEATURE NORMALIZATION (automatic for orders > 2)
use_normalization = max(data_poly_order, regressor_poly_order) > 2
normalization_method = 'symmetric'  # Maps to [-1, 1]

# Set random seed for reproducibility
torch.manual_seed(42)
np.random.seed(42)

print("Configuration:")
print(f"  Data polynomial order: {data_poly_order}")
print(f"  Regressor polynomial order: {regressor_poly_order}")
print(f"  Use normalization: {use_normalization}")
print(f"  Samples: {n_samples}, Noise std: {noise_std}")
print(f"  Epochs: {num_epochs}, Learning rate: {learning_rate}")
# Out:
# Configuration:
#   Data polynomial order: 4
#   Regressor polynomial order: 50
#   Use normalization: True
#   Samples: 50, Noise std: 5
#   Epochs: 50000, Learning rate: 0.001

# %% [markdown]
# ---
#
# ## Part 3: Data Generation
#
# ### Understanding the True Function
#
# We generate data from a polynomial function:
#
# $$y = a_0 + a_1 x + a_2 x^2 + a_3 x^3 + \epsilon$$
#
# where $\epsilon \sim \mathcal{N}(0, \sigma^2)$ is Gaussian noise.
#
# This noise creates the **irreducible error** — the best possible model still has error equal to $\sigma^2$.

# %%
def generate_data(coeffs_true, data_poly_order, n_samples=100, 
                  x_min=0, x_max=10, noise_std=0.5):
    """
    Generate synthetic polynomial data with noise.
    
    Args:
        coeffs_true: True polynomial coefficients [a₀, a₁, ..., aₙ]
        data_poly_order: Polynomial order
        n_samples: Number of data points
        x_min, x_max: Range for x values
        noise_std: Standard deviation of Gaussian noise
    
    Returns:
        x_t, y_t: Input and noisy output tensors
    """
    # Validate
    assert len(coeffs_true) == data_poly_order + 1
    
    # Generate x values uniformly
    x = torch.linspace(x_min, x_max, n_samples)
    
    # Compute true y values
    y_true = torch.zeros(n_samples)
    for i, coeff in enumerate(coeffs_true):
        y_true += coeff * (x ** i)
    
    # Add Gaussian noise
    noise = torch.randn(n_samples) * noise_std
    y_noisy = y_true + noise
    
    return x, y_noisy


# Generate data
logger.info("\n[STEP 1] Generating synthetic polynomial data...")
logger.info(f"Data polynomial order: {data_poly_order}")
logger.info(f"True coefficients: {coeffs_true}")

# x_range
x_min = 0
x_max = 10

x_t, y_t = generate_data(
    coeffs_true=coeffs_true,
    data_poly_order=data_poly_order,
    n_samples=n_samples,
    x_min=x_min,
    x_max=x_max,
    noise_std=noise_std
)

logger.info(f"Generated {n_samples} data points")
logger.info(f"x range: [{x_t.min():.2f}, {x_t.max():.2f}]")
logger.info(f"y range: [{y_t.min():.2f}, {y_t.max():.2f}]")
# Out:
# 2026-02-15 22:07:53,168 | INFO     | __main__:35 |
# [STEP 1] Generating synthetic polynomial data...
# 2026-02-15 22:07:53,168 | INFO     | __main__:36 | Data polynomial order: 4
# 2026-02-15 22:07:53,169 | INFO     | __main__:37 | True coefficients: [1.5, 0.4, 0.07, -0.02, 0.0005]
# 2026-02-15 22:07:53,170 | INFO     | __main__:52 | Generated 50 data points
# 2026-02-15 22:07:53,170 | INFO     | __main__:53 | x range: [0.00, 10.00]
# 2026-02-15 22:07:53,171 | INFO     | __main__:54 | y range: [-8.76, 11.50]

# %% [markdown]
# ### Visualize the Generated Data

# %%
# Plot the data
plt.figure(figsize=(10, 6))

# Scatter plot of noisy data
plt.scatter(x_t.numpy(), y_t.numpy(), alpha=0.5, s=30, label='Observed data')

# Plot true function (without noise)
x_dense = torch.linspace(x_min, x_max, 200)
y_true_dense = torch.zeros(200)
for i, coeff in enumerate(coeffs_true):
    y_true_dense += coeff * (x_dense ** i)

plt.plot(x_dense.numpy(), y_true_dense.numpy(), 'g--', 
         linewidth=2, label='True function (no noise)')

plt.xlabel('x', fontsize=12)
plt.ylabel('y', fontsize=12)
plt.title('Generated Data: Polynomial with Noise', fontsize=14)
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

print(f"\n✓ Data generated: {n_samples} points")
print(f"  True function: y = {coeffs_true[0]:.2f} + {coeffs_true[1]:.2f}x + {coeffs_true[2]:.2f}x² + {coeffs_true[3]:.2f}x³")
print(f"  Noise level (σ): {noise_std}")
# Out:
# ✓ Data generated: 50 points
#   True function: y = 1.50 + 0.40x + 0.07x² + -0.02x³
#   Noise level (σ): 5

# %% [markdown]
# ---
#
# ## Part 4: Feature Normalization
#
# ### Why Normalization is Critical
#
# When $x \in [0, 10]$ and we compute polynomial features:
#
# | Feature | Range | Magnitude |
# |---------|-------|----------|
# | $x^0$ | 1 | $10^0$ |
# | $x^1$ | [0, 10] | $10^1$ |
# | $x^2$ | [0, 100] | $10^2$ |
# | $x^3$ | [0, 1000] | $10^3$ ⚠️ |
# | $x^4$ | [0, 10,000] | $10^4$ 🚨 |
# | $x^5$ | [0, 100,000] | $10^5$ 💥 |
#
# **Problem:** Gradients explode → NaN values → training fails!
#
# **Solution:** Normalize $x$ to $[-1, 1]$ **before** computing powers:
# - $(x_{norm})^3$ stays in $[-1, 1]$ ✅
# - $(x_{norm})^5$ stays in $[-1, 1]$ ✅

# %%
# Apply normalization if needed
normalizer = None

if use_normalization:
    logger.info("\n[STEP 1.5] Applying feature normalization...")
    logger.info(f"⚠️  Polynomial order {max(data_poly_order, regressor_poly_order)} requires normalization!")
    
    normalizer = FeatureNormalizer(method=normalization_method)
    x_t_original = x_t.clone()
    x_t = normalizer.fit_transform(x_t)
    
    logger.info(f"Before: x ∈ [{x_t_original.min():.2f}, {x_t_original.max():.2f}]")
    logger.info(f"After:  x ∈ [{x_t.min():.2f}, {x_t.max():.2f}]")
    logger.info("✓ Features normalized to [-1, 1]")
    
    # Demonstrate the effect
    print("\nNormalization Effect:")
    for order in [1, 2, 3, 4, 5]:
        x_power = x_t ** order
        print(f"  x^{order}: range [{x_power.min():.2f}, {x_power.max():.2f}]")
else:
    logger.info("\n[STEP 1.5] Skipping normalization (order ≤ 2)")
# Out:
# 2026-02-15 22:07:53,288 | INFO     | __main__:5 |
# [STEP 1.5] Applying feature normalization...
# 2026-02-15 22:07:53,289 | INFO     | __main__:6 | ⚠️  Polynomial order 50 requires normalization!
# 2026-02-15 22:07:53,289 | INFO     | polynomial_tutorial.utils:76 | Fitted symmetric normalizer: mean=None, std=None, min=0.0, max=10.0
# 2026-02-15 22:07:53,290 | INFO     | __main__:12 | Before: x ∈ [0.00, 10.00]
# 2026-02-15 22:07:53,290 | INFO     | __main__:13 | After:  x ∈ [-1.00, 1.00]
# 2026-02-15 22:07:53,290 | INFO     | __main__:14 | ✓ Features normalized to [-1, 1]
#
# Normalization Effect:
#   x^1: range [-1.00, 1.00]
#   x^2: range [0.00, 1.00]
#   x^3: range [-1.00, 1.00]
#   x^4: range [0.00, 1.00]
#   x^5: range [-1.00, 1.00]

# %% [markdown]
# ---
#
# ## Part 5: Model Definition
#
# ### The PolynomialRegressor Class
#
# Our model implements:
#
# $$y = a_0 + a_1 x + a_2 x^2 + \cdots + a_n x^n$$
#
# **Key features:**
# - Arbitrary polynomial order
# - Learnable coefficients as `nn.Parameter`
# - Forward pass computes polynomial features and predictions

# %%
# Initialize the model
logger.info("\n[STEP 2] Initializing the polynomial regression model...")
logger.info(f"Regressor polynomial order: {regressor_poly_order}")

model = PolynomialRegressor(order=regressor_poly_order)
logger.info(f"Model initialized with {regressor_poly_order + 1} parameters")

# Analyze bias-variance scenario
if regressor_poly_order < data_poly_order:
    scenario = "UNDERFITTING"
    logger.info("⚠️  UNDERFITTING: Model order < Data order (High Bias)")
elif regressor_poly_order == data_poly_order:
    scenario = "GOOD FIT"
    logger.info("✓ GOOD FIT: Model order = Data order (Balanced)")
else:
    scenario = "OVERFITTING RISK"
    logger.info("⚠️  OVERFITTING RISK: Model order > Data order (High Variance)")

print(f"\nModel Summary:")
print(f"  Architecture: Polynomial regression (order {regressor_poly_order})")
print(f"  Parameters: {regressor_poly_order + 1} coefficients")
print(f"  Scenario: {scenario}")
print(f"\n{model}")
# Out:
# 2026-02-15 22:07:53,306 | INFO     | __main__:2 |
# [STEP 2] Initializing the polynomial regression model...
# 2026-02-15 22:07:53,306 | INFO     | __main__:3 | Regressor polynomial order: 50
# 2026-02-15 22:07:53,307 | INFO     | __main__:6 | Model initialized with 51 parameters
# 2026-02-15 22:07:53,307 | INFO     | __main__:17 | ⚠️  OVERFITTING RISK: Model order > Data order (High Variance)
#
# Model Summary:
#   Architecture: Polynomial regression (order 50)
#   Parameters: 51 coefficients
#   Scenario: OVERFITTING RISK
#
# PolynomialRegressor(order=50, y = 0.2218 + 0.0523x + 0.0347x^2 - 0.0197x^3 - 0.1055x^4 + 0.1278x^5 + 0.0145x^6 + 0.0231x^7 + 0.0057x^8 + 0.0426x^9 + 0.0575x^10 - 0.0642x^11 - 0.2206x^12 - 0.0751x^13 + 0.2814x^14 + 0.0360x^15 - 0.1341x^16 - 0.0585x^17 + 0.0536x^18 + 0.0525x^19 + 0.1141x^20 + 0.0052x^21 + 0.0728x^22 - 0.0711x^23 - 0.1049x^24 + 0.0604x^25 - 0.1722x^26 - 0.0828x^27 + 0.1335x^28 + 0.0484x^29 - 0.0198x^30 + 0.1268x^31 + 0.0785x^32 + 0.0029x^33 + 0.0641x^34 + 0.0091x^35 - 0.0389x^36 + 0.0528x^37 + 0.1031x^38 - 0.0705x^39 + 0.1013x^40 - 0.0331x^41 + 0.0518x^42 + 0.0340x^43 + 0.0720x^44 + 0.0411x^45 - 0.0573x^46 + 0.0507x^47 - 0.0475x^48 - 0.0492x^49 + 0.0270x^50)

# %% [markdown]
# ---
#
# ## Part 6: Training
#
# ### The Training Loop
#
# Standard gradient descent optimization:
#
# 1. **Forward pass:** Compute predictions
# 2. **Compute loss:** Mean Squared Error (MSE)
# 3. **Backward pass:** Compute gradients via autograd
# 4. **Update:** $\theta \leftarrow \theta - \alpha \nabla L(\theta)$
#
# **Special:** We track parameter evolution to visualize convergence!

# %%
# Train the model
logger.info("\n[STEP 3] Training the model...")
logger.info(f"Training on {'NORMALIZED' if use_normalization else 'ORIGINAL'} features")

trained_model, training_history = train_model(
    model=model,
    x_train=x_t,
    y_train=y_t,
    num_epochs=num_epochs,
    learning_rate=learning_rate,
    print_every=400,
    verbose=True
)

print(f"\n✓ Training completed!")
print(f"  Final loss: {training_history['loss'][-1]:.6f}")
# Out:
# 2026-02-15 22:07:53,323 | INFO     | __main__:2 |
# [STEP 3] Training the model...
# 2026-02-15 22:07:53,324 | INFO     | __main__:3 | Training on NORMALIZED features
# 2026-02-15 22:07:53,864 | INFO     | polynomial_tutorial.train:68 | ============================================================
# 2026-02-15 22:07:53,864 | INFO     | polynomial_tutorial.train:69 | Training Polynomial Regression Model
# 2026-02-15 22:07:53,865 | INFO     | polynomial_tutorial.train:70 | ============================================================
# 2026-02-15 22:07:53,865 | INFO     | polynomial_tutorial.train:71 | Model order: 50
# 2026-02-15 22:07:53,865 | INFO     | polynomial_tutorial.train:72 | Initial parameters: [0.2218075841665268, 0.05231655389070511, 0.03466466814279556, -0.019733143970370293, -0.10545889288187027, 0.12779955565929413, 0.014533767476677895, 0.023105137050151825, 0.005662181880325079, 0.04262961447238922, 0.057500507682561874, -0.0641724094748497, -0.22063985466957092, -0.07508030533790588, 0.28140270709991455, 0.035978734493255615, -0.13406795263290405, -0.05853705480694771, 0.053618814796209335, 0.05246226117014885, 0.11412016302347183, 0.005164359696209431, 0.07281095534563065, -0.07106419652700424, -0.10494661331176758, 0.06038988381624222, -0.17222951352596283, -0.08277688920497894, 0.1334702968597412, 0.048353929072618484, -0.019756168127059937, 0.12683114409446716, 0.07845868915319443, 0.002864718670025468, 0.0640755295753479, 0.009115186519920826, -0.0389065220952034, 0.05279165133833885, 0.10310915857553482, -0.07047650218009949, 0.10131483525037766, -0.0330817848443985, 0.051769305020570755, 0.03398909792304039, 0.07199674844741821, 0.041140761226415634, -0.05733190104365349, 0.05068639665842056, -0.04752098396420479, -0.04920265078544617, 0.027037356048822403]
# 2026-02-15 22:07:53,865 | INFO     | polynomial_tutorial.train:73 | Learning rate: 0.001
# 2026-02-15 22:07:53,866 | INFO     | polynomial_tutorial.train:74 | Number of epochs: 50000
# 2026-02-15 22:07:53,866 | INFO     | polynomial_tutorial.train:75 | Number of training samples: 50
# 2026-02-15 22:07:53,866 | INFO     | polynomial_tutorial.train:76 | ============================================================
# 2026-02-15 22:07:53,980 | INFO     | polynomial_tutorial.train:114 | Epoch [ 400/50000] | Loss: 30.507784 | Params: ['1.2170', '-0.1843', '-0.0004', '-0.1634', '-0.0001', '-0.0805', '0.0003', '-0.1250', '0.0000', '-0.1141', '0.0595', '-0.1930', '0.0003', '-0.1978', '0.2908', '-0.1008', '0.0004', '-0.1669', '0.0652', '-0.0808', '0.1260', '-0.0919', '0.0848', '-0.1573', '0.0005', '-0.0586', '0.0002', '-0.1557', '0.1449', '-0.0516', '0.0076', '-0.0274', '0.0894', '-0.0555', '0.0747', '-0.0486', '0.0039', '-0.0322', '0.1134', '-0.1129', '0.1114', '-0.0716', '0.0618', '-0.0268', '0.0819', '-0.0218', '0.0017', '-0.0176', '0.0024', '-0.0751', '0.0368']
# 2026-02-15 22:07:54,095 | INFO     | polynomial_tutorial.train:114 | Epoch [ 800/50000] | Loss: 29.837189 | Params: ['1.6716', '-0.2714', '-0.0343', '-0.2055', '-0.0004', '-0.1301', '0.0003', '-0.1819', '-0.0002', '-0.1745', '0.0023', '-0.2534', '0.0001', '-0.2560', '0.2535', '-0.1550', '0.0003', '-0.2161', '0.0372', '-0.1245', '0.1008', '-0.1299', '0.0616', '-0.1897', '0.0005', '-0.0855', '0.0003', '-0.1773', '0.1255', '-0.0680', '0.0004', '-0.0391', '0.0714', '-0.0627', '0.0573', '-0.0516', '0.0002', '-0.0313', '0.0968', '-0.1084', '0.0952', '-0.0637', '0.0459', '-0.0158', '0.0664', '-0.0078', '0.0003', '-0.0010', '0.0001', '-0.0560', '0.0221']
# 2026-02-15 22:07:54,207 | INFO     | polynomial_tutorial.train:114 | Epoch [1200/50000] | Loss: 29.627880 | Params: ['1.9005', '-0.3119', '-0.1286', '-0.2114', '-0.0003', '-0.1489', '-0.0003', '-0.2116', '0.0002', '-0.2102', '-0.0000', '-0.2912', '0.0004', '-0.2928', '0.2101', '-0.1890', '0.0003', '-0.2462', '0.0054', '-0.1500', '0.0726', '-0.1504', '0.0361', '-0.2051', '0.0005', '-0.0958', '0.0001', '-0.1828', '0.1050', '-0.0688', '0.0002', '-0.0355', '0.0529', '-0.0549', '0.0396', '-0.0399', '0.0005', '-0.0159', '0.0803', '-0.0895', '0.0793', '-0.0417', '0.0304', '-0.0004', '0.0513', '0.0000', '0.0006', '-0.0002', '0.0002', '-0.0234', '0.0081']
# 2026-02-15 22:07:54,319 | INFO     | polynomial_tutorial.train:114 | Epoch [1600/50000] | Loss: 29.522001 | Params: ['2.0315', '-0.3325', '-0.2417', '-0.2020', '-0.0002', '-0.1548', '-0.0003', '-0.2301', '-0.0002', '-0.2359', '0.0001', '-0.3197', '0.0003', '-0.3211', '0.1704', '-0.2151', '0.0001', '-0.2688', '0.0001', '-0.1683', '0.0489', '-0.1641', '0.0153', '-0.2140', '0.0005', '-0.1000', '0.0005', '-0.1822', '0.0895', '-0.0638', '0.0001', '-0.0262', '0.0393', '-0.0416', '0.0268', '-0.0228', '0.0004', '-0.0000', '0.0688', '-0.0656', '0.0683', '-0.0147', '0.0199', '-0.0005', '0.0412', '-0.0003', '0.0005', '-0.0005', '0.0005', '-0.0005', '0.0004']
# 2026-02-15 22:07:54,431 | INFO     | polynomial_tutorial.train:114 | Epoch [2000/50000] | Loss: 29.451519 | Params: ['2.1174', '-0.3434', '-0.3571', '-0.1850', '-0.0003', '-0.1543', '-0.0002', '-0.2428', '0.0002', '-0.2564', '-0.0001', '-0.3435', '-0.0001', '-0.3452', '0.1365', '-0.2373', '0.0003', '-0.2877', '-0.0000', '-0.1831', '0.0309', '-0.1744', '0.0000', '-0.2197', '-0.0000', '-0.1010', '0.0005', '-0.1787', '0.0794', '-0.0560', '0.0001', '-0.0142', '0.0312', '-0.0256', '0.0194', '-0.0030', '0.0003', '-0.0002', '0.0626', '-0.0391', '0.0626', '-0.0001', '0.0147', '0.0001', '0.0364', '-0.0002', '0.0003', '-0.0003', '0.0000', '-0.0004', '0.0002']
# 2026-02-15 22:07:54,544 | INFO     | polynomial_tutorial.train:114 | Epoch [2400/50000] | Loss: 29.397282 | Params: ['2.1808', '-0.3493', '-0.4688', '-0.1638', '-0.0003', '-0.1501', '0.0003', '-0.2522', '0.0002', '-0.2738', '0.0003', '-0.3645', '0.0000', '-0.3666', '0.1082', '-0.2569', '0.0005', '-0.3042', '0.0003', '-0.1957', '0.0180', '-0.1827', '0.0001', '-0.2234', '0.0002', '-0.1001', '0.0006', '-0.1734', '0.0740', '-0.0462', '0.0006', '-0.0003', '0.0277', '-0.0079', '0.0166', '-0.0002', '0.0004', '-0.0005', '0.0609', '-0.0110', '0.0613', '-0.0002', '0.0138', '-0.0002', '0.0359', '-0.0003', '0.0007', '-0.0004', '0.0008', '-0.0001', '0.0013']
# 2026-02-15 22:07:54,658 | INFO     | polynomial_tutorial.train:114 | Epoch [2800/50000] | Loss: 29.353342 | Params: ['2.2316', '-0.3527', '-0.5752', '-0.1400', '-0.0002', '-0.1434', '0.0001', '-0.2593', '0.0003', '-0.2891', '-0.0001', '-0.3835', '0.0002', '-0.3860', '0.0846', '-0.2747', '0.0003', '-0.3189', '0.0001', '-0.2066', '0.0092', '-0.1892', '0.0004', '-0.2254', '0.0000', '-0.0977', '0.0000', '-0.1665', '0.0723', '-0.0351', '0.0003', '-0.0000', '0.0276', '-0.0001', '0.0171', '-0.0002', '0.0015', '-0.0001', '0.0624', '-0.0001', '0.0633', '-0.0002', '0.0161', '-0.0004', '0.0386', '-0.0003', '0.0037', '-0.0004', '0.0041', '-0.0003', '0.0049']
# 2026-02-15 22:07:54,781 | INFO     | polynomial_tutorial.train:114 | Epoch [3200/50000] | Loss: 29.315975 | Params: ['2.2745', '-0.3545', '-0.6759', '-0.1144', '-0.0002', '-0.1347', '0.0003', '-0.2644', '0.0003', '-0.3023', '0.0001', '-0.4004', '-0.0000', '-0.4034', '0.0645', '-0.2904', '0.0005', '-0.3317', '0.0005', '-0.2155', '0.0033', '-0.1939', '0.0005', '-0.2257', '0.0002', '-0.0934', '0.0003', '-0.1578', '0.0730', '-0.0221', '0.0019', '-0.0004', '0.0299', '-0.0002', '0.0200', '-0.0003', '0.0048', '-0.0004', '0.0662', '-0.0002', '0.0674', '-0.0003', '0.0206', '-0.0002', '0.0433', '-0.0005', '0.0087', '-0.0000', '0.0093', '-0.0001', '0.0104']
# 2026-02-15 22:07:54,915 | INFO     | polynomial_tutorial.train:114 | Epoch [3600/50000] | Loss: 29.282480 | Params: ['2.3120', '-0.3565', '-0.7714', '-0.0882', '-0.0001', '-0.1251', '0.0000', '-0.2684', '0.0004', '-0.3144', '0.0000', '-0.4161', '0.0003', '-0.4197', '0.0470', '-0.3051', '-0.0000', '-0.3434', '0.0002', '-0.2234', '0.0001', '-0.1975', '0.0001', '-0.2248', '0.0003', '-0.0881', '0.0017', '-0.1481', '0.0754', '-0.0081', '0.0051', '-0.0004', '0.0336', '-0.0005', '0.0242', '0.0000', '0.0095', '-0.0003', '0.0712', '-0.0005', '0.0728', '-0.0000', '0.0262', '-0.0001', '0.0493', '-0.0003', '0.0149', '-0.0005', '0.0158', '-0.0001', '0.0171']
# 2026-02-15 22:07:55,027 | INFO     | polynomial_tutorial.train:114 | Epoch [4000/50000] | Loss: 29.252243 | Params: ['2.3456', '-0.3591', '-0.8621', '-0.0619', '0.0001', '-0.1152', '0.0003', '-0.2719', '0.0004', '-0.3258', '0.0000', '-0.4312', '0.0003', '-0.4353', '0.0314', '-0.3190', '0.0006', '-0.3543', '0.0002', '-0.2305', '0.0006', '-0.2003', '0.0003', '-0.2232', '0.0015', '-0.0820', '0.0041', '-0.1376', '0.0786', '-0.0001', '0.0090', '-0.0002', '0.0382', '-0.0001', '0.0292', '-0.0002', '0.0149', '-0.0000', '0.0769', '-0.0001', '0.0788', '-0.0003', '0.0325', '-0.0000', '0.0558', '-0.0000', '0.0217', '-0.0002', '0.0228', '-0.0001', '0.0242']
# 2026-02-15 22:07:55,141 | INFO     | polynomial_tutorial.train:114 | Epoch [4400/50000] | Loss: 29.225229 | Params: ['2.3762', '-0.3622', '-0.9484', '-0.0356', '-0.0001', '-0.1048', '0.0001', '-0.2747', '0.0000', '-0.3366', '0.0003', '-0.4456', '0.0003', '-0.4501', '0.0172', '-0.3322', '0.0006', '-0.3644', '0.0005', '-0.2368', '0.0002', '-0.2024', '0.0007', '-0.2208', '0.0033', '-0.0752', '0.0071', '-0.1264', '0.0824', '-0.0002', '0.0134', '-0.0005', '0.0431', '-0.0002', '0.0345', '-0.0002', '0.0205', '-0.0003', '0.0829', '-0.0002', '0.0850', '-0.0004', '0.0390', '-0.0004', '0.0624', '-0.0002', '0.0286', '-0.0004', '0.0298', '0.0001', '0.0315']
# 2026-02-15 22:07:55,254 | INFO     | polynomial_tutorial.train:114 | Epoch [4800/50000] | Loss: 29.200294 | Params: ['2.4044', '-0.3662', '-1.0304', '-0.0094', '-0.0002', '-0.0943', '0.0002', '-0.2773', '-0.0000', '-0.3469', '0.0005', '-0.4594', '0.0005', '-0.4643', '0.0041', '-0.3447', '0.0003', '-0.3740', '0.0005', '-0.2425', '0.0004', '-0.2039', '0.0017', '-0.2178', '0.0056', '-0.0677', '0.0104', '-0.1145', '0.0865', '-0.0003', '0.0181', '-0.0002', '0.0482', '-0.0002', '0.0400', '-0.0002', '0.0263', '-0.0005', '0.0889', '-0.0002', '0.0912', '-0.0005', '0.0454', '-0.0001', '0.0691', '-0.0004', '0.0354', '-0.0001', '0.0368', '-0.0004', '0.0387']
# 2026-02-15 22:07:55,368 | INFO     | polynomial_tutorial.train:114 | Epoch [5200/50000] | Loss: 29.178738 | Params: ['2.4306', '-0.3702', '-1.1086', '-0.0003', '-0.0003', '-0.0833', '0.0004', '-0.2792', '-0.0001', '-0.3566', '0.0003', '-0.4726', '0.0005', '-0.4779', '0.0004', '-0.3566', '0.0001', '-0.3828', '0.0003', '-0.2476', '0.0004', '-0.2046', '0.0028', '-0.2142', '0.0081', '-0.0596', '0.0138', '-0.1020', '0.0906', '-0.0003', '0.0227', '-0.0004', '0.0532', '-0.0002', '0.0453', '-0.0002', '0.0319', '-0.0001', '0.0947', '-0.0003', '0.0972', '0.0000', '0.0516', '-0.0005', '0.0755', '0.0000', '0.0419', '-0.0003', '0.0435', '-0.0002', '0.0455']
# 2026-02-15 22:07:55,481 | INFO     | polynomial_tutorial.train:114 | Epoch [5600/50000] | Loss: 29.159904 | Params: ['2.4549', '-0.3721', '-1.1834', '-0.0003', '-0.0001', '-0.0707', '0.0000', '-0.2797', '0.0001', '-0.3649', '0.0005', '-0.4844', '0.0001', '-0.4902', '0.0001', '-0.3673', '0.0002', '-0.3906', '0.0003', '-0.2515', '0.0004', '-0.2044', '0.0040', '-0.2095', '0.0104', '-0.0505', '0.0170', '-0.0885', '0.0944', '-0.0001', '0.0270', '-0.0003', '0.0578', '-0.0005', '0.0503', '-0.0004', '0.0370', '0.0000', '0.1001', '-0.0000', '0.1028', '-0.0004', '0.0573', '0.0000', '0.0813', '0.0001', '0.0479', '-0.0003', '0.0497', '-0.0004', '0.0519']
# 2026-02-15 22:07:55,596 | INFO     | polynomial_tutorial.train:114 | Epoch [6000/50000] | Loss: 29.142513 | Params: ['2.4779', '-0.3730', '-1.2548', '-0.0005', '-0.0003', '-0.0572', '-0.0002', '-0.2793', '-0.0001', '-0.3725', '-0.0000', '-0.4956', '0.0005', '-0.5019', '0.0003', '-0.3774', '0.0001', '-0.3977', '0.0006', '-0.2548', '0.0006', '-0.2035', '0.0051', '-0.2043', '0.0127', '-0.0408', '0.0201', '-0.0745', '0.0981', '-0.0005', '0.0311', '-0.0003', '0.0622', '-0.0002', '0.0549', '-0.0002', '0.0419', '-0.0000', '0.1051', '-0.0005', '0.1080', '-0.0003', '0.0626', '-0.0002', '0.0868', '-0.0000', '0.0535', '-0.0004', '0.0554', '-0.0002', '0.0577']
# 2026-02-15 22:07:55,710 | INFO     | polynomial_tutorial.train:114 | Epoch [6400/50000] | Loss: 29.126678 | Params: ['2.4997', '-0.3735', '-1.3229', '-0.0003', '-0.0003', '-0.0433', '0.0003', '-0.2786', '-0.0001', '-0.3796', '0.0005', '-0.5064', '0.0004', '-0.5132', '0.0005', '-0.3871', '0.0003', '-0.4044', '0.0005', '-0.2579', '0.0003', '-0.2024', '0.0064', '-0.1987', '0.0150', '-0.0309', '0.0231', '-0.0603', '0.1016', '0.0000', '0.0350', '-0.0000', '0.0664', '-0.0004', '0.0593', '-0.0004', '0.0465', '-0.0004', '0.1098', '-0.0002', '0.1128', '-0.0001', '0.0676', '-0.0002', '0.0918', '0.0001', '0.0587', '-0.0004', '0.0607', '-0.0004', '0.0631']
# 2026-02-15 22:07:55,823 | INFO     | polynomial_tutorial.train:114 | Epoch [6800/50000] | Loss: 29.112083 | Params: ['2.5204', '-0.3738', '-1.3879', '-0.0004', '-0.0002', '-0.0291', '0.0003', '-0.2776', '0.0001', '-0.3865', '0.0002', '-0.5169', '0.0004', '-0.5242', '0.0001', '-0.3966', '0.0004', '-0.4110', '0.0000', '-0.2607', '0.0001', '-0.2010', '0.0077', '-0.1930', '0.0173', '-0.0208', '0.0260', '-0.0458', '0.1050', '-0.0000', '0.0387', '-0.0002', '0.0704', '-0.0004', '0.0635', '-0.0004', '0.0508', '-0.0001', '0.1143', '-0.0003', '0.1173', '-0.0003', '0.0722', '-0.0001', '0.0966', '-0.0003', '0.0636', '-0.0002', '0.0657', '-0.0004', '0.0681']
# 2026-02-15 22:07:55,936 | INFO     | polynomial_tutorial.train:114 | Epoch [7200/50000] | Loss: 29.098501 | Params: ['2.5402', '-0.3742', '-1.4498', '-0.0005', '-0.0002', '-0.0149', '0.0001', '-0.2765', '0.0003', '-0.3933', '0.0003', '-0.5273', '-0.0000', '-0.5352', '0.0001', '-0.4060', '0.0002', '-0.4175', '0.0005', '-0.2635', '0.0001', '-0.1996', '0.0090', '-0.1873', '0.0196', '-0.0106', '0.0289', '-0.0314', '0.1084', '-0.0005', '0.0424', '-0.0004', '0.0742', '-0.0004', '0.0674', '-0.0004', '0.0549', '-0.0003', '0.1184', '-0.0004', '0.1216', '-0.0005', '0.0766', '0.0000', '0.1010', '-0.0000', '0.0681', '0.0000', '0.0703', '-0.0004', '0.0728']
# 2026-02-15 22:07:56,050 | INFO     | polynomial_tutorial.train:114 | Epoch [7600/50000] | Loss: 29.085930 | Params: ['2.5590', '-0.3746', '-1.5088', '-0.0000', '-0.0002', '-0.0006', '-0.0001', '-0.2753', '0.0000', '-0.4000', '0.0001', '-0.5377', '0.0002', '-0.5461', '0.0001', '-0.4153', '0.0004', '-0.4239', '0.0005', '-0.2662', '0.0003', '-0.1982', '0.0105', '-0.1815', '0.0218', '-0.0004', '0.0318', '-0.0168', '0.1116', '-0.0005', '0.0458', '-0.0005', '0.0779', '-0.0003', '0.0712', '-0.0004', '0.0587', '0.0000', '0.1224', '-0.0005', '0.1256', '-0.0001', '0.0806', '-0.0004', '0.1051', '-0.0004', '0.0723', '-0.0004', '0.0745', '-0.0005', '0.0772']
# 2026-02-15 22:07:56,164 | INFO     | polynomial_tutorial.train:114 | Epoch [8000/50000] | Loss: 29.075230 | Params: ['2.5769', '-0.3742', '-1.5650', '-0.0005', '0.0000', '-0.0005', '0.0001', '-0.2734', '0.0003', '-0.4061', '0.0001', '-0.5474', '0.0005', '-0.5564', '0.0005', '-0.4242', '0.0003', '-0.4299', '0.0002', '-0.2685', '0.0006', '-0.1963', '0.0120', '-0.1752', '0.0241', '0.0000', '0.0346', '-0.0019', '0.1147', '0.0000', '0.0492', '-0.0002', '0.0814', '-0.0004', '0.0748', '0.0000', '0.0624', '-0.0004', '0.1261', '-0.0002', '0.1293', '-0.0005', '0.0844', '0.0001', '0.1090', '-0.0004', '0.0762', '-0.0004', '0.0785', '-0.0002', '0.0812']
# 2026-02-15 22:07:56,277 | INFO     | polynomial_tutorial.train:114 | Epoch [8400/50000] | Loss: 29.065969 | Params: ['2.5940', '-0.3724', '-1.6186', '-0.0003', '-0.0001', '-0.0004', '-0.0001', '-0.2703', '-0.0001', '-0.4111', '0.0004', '-0.5562', '0.0003', '-0.5658', '0.0003', '-0.4320', '0.0006', '-0.4349', '0.0001', '-0.2698', '0.0011', '-0.1935', '0.0135', '-0.1681', '0.0265', '-0.0006', '0.0374', '-0.0000', '0.1178', '-0.0005', '0.0525', '-0.0004', '0.0847', '-0.0005', '0.0782', '-0.0001', '0.0658', '-0.0002', '0.1296', '-0.0005', '0.1329', '-0.0002', '0.0880', '0.0001', '0.1126', '-0.0003', '0.0798', '-0.0004', '0.0822', '-0.0004', '0.0850']
# 2026-02-15 22:07:56,389 | INFO     | polynomial_tutorial.train:114 | Epoch [8800/50000] | Loss: 29.057585 | Params: ['2.6103', '-0.3697', '-1.6697', '-0.0002', '0.0000', '-0.0005', '0.0000', '-0.2663', '-0.0000', '-0.4151', '0.0003', '-0.5640', '-0.0000', '-0.5743', '0.0004', '-0.4391', '0.0005', '-0.4391', '0.0002', '-0.2704', '0.0016', '-0.1900', '0.0152', '-0.1603', '0.0288', '-0.0004', '0.0401', '-0.0004', '0.1208', '-0.0004', '0.0556', '-0.0005', '0.0879', '-0.0004', '0.0815', '-0.0001', '0.0691', '-0.0005', '0.1328', '-0.0001', '0.1361', '-0.0005', '0.0913', '0.0001', '0.1159', '-0.0002', '0.0831', '-0.0004', '0.0856', '0.0000', '0.0884']
# 2026-02-15 22:07:56,504 | INFO     | polynomial_tutorial.train:114 | Epoch [9200/50000] | Loss: 29.050011 | Params: ['2.6259', '-0.3667', '-1.7184', '-0.0002', '0.0001', '-0.0001', '0.0003', '-0.2618', '0.0005', '-0.4186', '0.0004', '-0.5713', '0.0003', '-0.5823', '0.0003', '-0.4456', '0.0002', '-0.4429', '0.0006', '-0.2705', '0.0023', '-0.1860', '0.0169', '-0.1521', '0.0311', '-0.0004', '0.0428', '-0.0003', '0.1237', '-0.0004', '0.0586', '-0.0002', '0.0910', '0.0001', '0.0845', '-0.0003', '0.0722', '-0.0003', '0.1359', '-0.0004', '0.1392', '-0.0004', '0.0943', '-0.0001', '0.1190', '-0.0002', '0.0862', '0.0001', '0.0887', '-0.0004', '0.0916']
# 2026-02-15 22:07:56,621 | INFO     | polynomial_tutorial.train:114 | Epoch [9600/50000] | Loss: 29.042835 | Params: ['2.6406', '-0.3636', '-1.7649', '-0.0000', '0.0002', '-0.0005', '0.0001', '-0.2568', '0.0001', '-0.4218', '-0.0000', '-0.5782', '0.0005', '-0.5899', '0.0001', '-0.4518', '0.0001', '-0.4462', '0.0005', '-0.2703', '0.0031', '-0.1817', '0.0186', '-0.1435', '0.0334', '-0.0001', '0.0454', '0.0000', '0.1265', '-0.0001', '0.0615', '-0.0001', '0.0940', '-0.0004', '0.0875', '-0.0002', '0.0751', '0.0001', '0.1388', '0.0001', '0.1421', '0.0000', '0.0972', '-0.0000', '0.1218', '-0.0000', '0.0891', '-0.0004', '0.0916', '0.0001', '0.0945']
# 2026-02-15 22:07:56,736 | INFO     | polynomial_tutorial.train:114 | Epoch [10000/50000] | Loss: 29.036537 | Params: ['2.6547', '-0.3608', '-1.8092', '-0.0003', '0.0002', '-0.0001', '-0.0001', '-0.2517', '0.0001', '-0.4247', '0.0002', '-0.5849', '-0.0000', '-0.5972', '0.0002', '-0.4577', '0.0003', '-0.4494', '0.0006', '-0.2698', '0.0041', '-0.1772', '0.0204', '-0.1347', '0.0357', '-0.0002', '0.0481', '0.0000', '0.1293', '-0.0002', '0.0643', '-0.0005', '0.0968', '-0.0000', '0.0903', '-0.0005', '0.0778', '0.0001', '0.1415', '-0.0004', '0.1447', '0.0000', '0.0998', '-0.0004', '0.1244', '-0.0003', '0.0917', '-0.0001', '0.0942', '0.0001', '0.0972']
# 2026-02-15 22:07:56,852 | INFO     | polynomial_tutorial.train:114 | Epoch [10400/50000] | Loss: 29.030859 | Params: ['2.6682', '-0.3581', '-1.8514', '-0.0005', '-0.0000', '-0.0002', '0.0003', '-0.2464', '0.0003', '-0.4274', '0.0005', '-0.5914', '0.0006', '-0.6045', '0.0000', '-0.4635', '0.0001', '-0.4524', '0.0002', '-0.2692', '0.0051', '-0.1725', '0.0223', '-0.1257', '0.0381', '-0.0001', '0.0507', '-0.0005', '0.1320', '-0.0002', '0.0671', '-0.0001', '0.0995', '-0.0001', '0.0929', '-0.0000', '0.0804', '-0.0004', '0.1440', '-0.0002', '0.1472', '-0.0005', '0.1023', '0.0000', '0.1269', '-0.0004', '0.0941', '-0.0003', '0.0966', '-0.0003', '0.0996']
# 2026-02-15 22:07:56,968 | INFO     | polynomial_tutorial.train:114 | Epoch [10800/50000] | Loss: 29.025398 | Params: ['2.6810', '-0.3556', '-1.8917', '-0.0002', '0.0001', '-0.0003', '0.0000', '-0.2410', '0.0002', '-0.4300', '0.0002', '-0.5978', '0.0004', '-0.6115', '0.0002', '-0.4692', '0.0002', '-0.4553', '0.0000', '-0.2685', '0.0062', '-0.1677', '0.0242', '-0.1166', '0.0404', '-0.0005', '0.0532', '-0.0002', '0.1347', '-0.0000', '0.0697', '-0.0003', '0.1021', '-0.0001', '0.0954', '-0.0001', '0.0829', '-0.0001', '0.1464', '-0.0005', '0.1495', '-0.0002', '0.1045', '-0.0001', '0.1291', '-0.0004', '0.0963', '-0.0004', '0.0988', '-0.0001', '0.1018']
# 2026-02-15 22:07:57,083 | INFO     | polynomial_tutorial.train:114 | Epoch [11200/50000] | Loss: 29.020529 | Params: ['2.6932', '-0.3534', '-1.9302', '-0.0004', '-0.0002', '-0.0002', '0.0002', '-0.2355', '0.0002', '-0.4326', '0.0005', '-0.6041', '0.0001', '-0.6185', '0.0001', '-0.4747', '0.0005', '-0.4581', '0.0006', '-0.2676', '0.0074', '-0.1628', '0.0261', '-0.1075', '0.0428', '-0.0002', '0.0557', '-0.0005', '0.1372', '-0.0004', '0.0723', '-0.0003', '0.1045', '-0.0000', '0.0978', '-0.0001', '0.0851', '-0.0004', '0.1486', '-0.0001', '0.1517', '0.0000', '0.1066', '-0.0001', '0.1311', '-0.0003', '0.0983', '-0.0004', '0.1008', '-0.0004', '0.1038']
# 2026-02-15 22:07:57,199 | INFO     | polynomial_tutorial.train:114 | Epoch [11600/50000] | Loss: 29.015903 | Params: ['2.7048', '-0.3514', '-1.9668', '-0.0001', '-0.0002', '-0.0002', '0.0002', '-0.2300', '0.0004', '-0.4350', '0.0002', '-0.6104', '0.0002', '-0.6255', '0.0003', '-0.4802', '0.0004', '-0.4608', '0.0007', '-0.2667', '0.0087', '-0.1579', '0.0281', '-0.0982', '0.0451', '-0.0005', '0.0582', '-0.0001', '0.1397', '-0.0001', '0.0747', '-0.0003', '0.1069', '-0.0005', '0.1001', '-0.0000', '0.0873', '-0.0001', '0.1506', '-0.0002', '0.1536', '-0.0002', '0.1085', '-0.0001', '0.1330', '-0.0002', '0.1002', '-0.0004', '0.1026', '0.0000', '0.1056']
# 2026-02-15 22:07:57,314 | INFO     | polynomial_tutorial.train:114 | Epoch [12000/50000] | Loss: 29.011694 | Params: ['2.7158', '-0.3496', '-2.0018', '-0.0004', '-0.0002', '-0.0001', '-0.0001', '-0.2244', '0.0001', '-0.4374', '0.0003', '-0.6165', '0.0000', '-0.6323', '0.0002', '-0.4857', '0.0005', '-0.4634', '0.0009', '-0.2658', '0.0101', '-0.1528', '0.0301', '-0.0890', '0.0474', '-0.0001', '0.0607', '-0.0003', '0.1422', '-0.0004', '0.0771', '-0.0002', '0.1092', '-0.0003', '0.1022', '0.0001', '0.0893', '-0.0002', '0.1526', '-0.0003', '0.1554', '-0.0004', '0.1102', '0.0000', '0.1346', '-0.0000', '0.1018', '-0.0003', '0.1042', '-0.0002', '0.1072']
# 2026-02-15 22:07:57,430 | INFO     | polynomial_tutorial.train:114 | Epoch [12400/50000] | Loss: 29.007816 | Params: ['2.7264', '-0.3479', '-2.0351', '-0.0002', '-0.0001', '-0.0000', '0.0000', '-0.2187', '0.0005', '-0.4398', '0.0004', '-0.6227', '0.0003', '-0.6391', '0.0003', '-0.4910', '0.0002', '-0.4660', '0.0013', '-0.2648', '0.0115', '-0.1478', '0.0322', '-0.0796', '0.0498', '-0.0003', '0.0631', '-0.0004', '0.1446', '-0.0000', '0.0794', '-0.0001', '0.1114', '-0.0000', '0.1043', '-0.0004', '0.0912', '-0.0004', '0.1543', '-0.0004', '0.1571', '-0.0000', '0.1118', '-0.0005', '0.1361', '-0.0004', '0.1032', '-0.0002', '0.1056', '-0.0003', '0.1086']
# 2026-02-15 22:07:57,545 | INFO     | polynomial_tutorial.train:114 | Epoch [12800/50000] | Loss: 29.004261 | Params: ['2.7365', '-0.3465', '-2.0670', '0.0000', '-0.0001', '-0.0005', '0.0003', '-0.2130', '0.0003', '-0.4421', '0.0004', '-0.6287', '0.0003', '-0.6458', '0.0001', '-0.4964', '0.0000', '-0.4686', '0.0018', '-0.2637', '0.0131', '-0.1427', '0.0342', '-0.0703', '0.0521', '-0.0004', '0.0655', '-0.0005', '0.1469', '-0.0002', '0.0816', '0.0000', '0.1135', '-0.0004', '0.1062', '-0.0002', '0.0930', '0.0001', '0.1560', '-0.0004', '0.1586', '-0.0002', '0.1132', '-0.0004', '0.1375', '-0.0002', '0.1045', '-0.0001', '0.1069', '-0.0005', '0.1098']
# 2026-02-15 22:07:57,661 | INFO     | polynomial_tutorial.train:114 | Epoch [13200/50000] | Loss: 29.000906 | Params: ['2.7460', '-0.3452', '-2.0974', '-0.0004', '-0.0001', '-0.0004', '0.0003', '-0.2073', '0.0001', '-0.4444', '0.0001', '-0.6347', '0.0006', '-0.6525', '0.0001', '-0.5016', '0.0001', '-0.4711', '0.0024', '-0.2626', '0.0146', '-0.1375', '0.0363', '-0.0609', '0.0544', '-0.0005', '0.0679', '-0.0000', '0.1492', '-0.0004', '0.0838', '-0.0004', '0.1154', '-0.0001', '0.1080', '-0.0000', '0.0947', '-0.0000', '0.1575', '-0.0004', '0.1600', '-0.0003', '0.1145', '-0.0002', '0.1387', '0.0000', '0.1057', '0.0000', '0.1080', '0.0000', '0.1108']
# 2026-02-15 22:07:57,777 | INFO     | polynomial_tutorial.train:114 | Epoch [13600/50000] | Loss: 28.997726 | Params: ['2.7552', '-0.3440', '-2.1264', '-0.0002', '-0.0003', '-0.0002', '0.0004', '-0.2016', '0.0005', '-0.4466', '0.0003', '-0.6407', '0.0006', '-0.6592', '0.0004', '-0.5069', '0.0002', '-0.4735', '0.0030', '-0.2615', '0.0163', '-0.1324', '0.0385', '-0.0514', '0.0567', '0.0000', '0.0702', '-0.0001', '0.1515', '-0.0005', '0.0859', '-0.0003', '0.1174', '-0.0004', '0.1098', '-0.0004', '0.0962', '-0.0001', '0.1589', '-0.0004', '0.1613', '-0.0004', '0.1157', '-0.0001', '0.1397', '-0.0004', '0.1066', '-0.0004', '0.1089', '-0.0001', '0.1117']
# 2026-02-15 22:07:57,893 | INFO     | polynomial_tutorial.train:114 | Epoch [14000/50000] | Loss: 28.994854 | Params: ['2.7639', '-0.3429', '-2.1541', '-0.0000', '0.0000', '-0.0000', '0.0001', '-0.1958', '0.0002', '-0.4488', '0.0003', '-0.6467', '0.0003', '-0.6659', '0.0003', '-0.5121', '0.0006', '-0.4760', '0.0038', '-0.2604', '0.0180', '-0.1272', '0.0406', '-0.0420', '0.0590', '-0.0001', '0.0725', '-0.0001', '0.1537', '-0.0001', '0.0879', '-0.0001', '0.1192', '-0.0001', '0.1114', '-0.0002', '0.0977', '-0.0002', '0.1602', '-0.0004', '0.1624', '0.0000', '0.1167', '0.0001', '0.1406', '-0.0001', '0.1075', '-0.0003', '0.1097', '-0.0002', '0.1125']
# 2026-02-15 22:07:58,009 | INFO     | polynomial_tutorial.train:114 | Epoch [14400/50000] | Loss: 28.992218 | Params: ['2.7722', '-0.3419', '-2.1805', '-0.0005', '0.0000', '-0.0004', '-0.0001', '-0.1900', '0.0005', '-0.4509', '0.0001', '-0.6526', '0.0003', '-0.6725', '0.0003', '-0.5173', '0.0005', '-0.4784', '0.0047', '-0.2592', '0.0197', '-0.1220', '0.0428', '-0.0325', '0.0613', '-0.0001', '0.0748', '-0.0001', '0.1558', '-0.0002', '0.0899', '-0.0005', '0.1209', '-0.0004', '0.1129', '0.0000', '0.0990', '-0.0003', '0.1613', '-0.0004', '0.1634', '-0.0001', '0.1176', '-0.0004', '0.1414', '-0.0005', '0.1082', '-0.0001', '0.1103', '-0.0003', '0.1131']
# 2026-02-15 22:07:58,127 | INFO     | polynomial_tutorial.train:114 | Epoch [14800/50000] | Loss: 28.989708 | Params: ['2.7801', '-0.3411', '-2.2057', '-0.0003', '-0.0002', '-0.0002', '0.0003', '-0.1842', '0.0000', '-0.4531', '0.0003', '-0.6585', '0.0005', '-0.6790', '0.0006', '-0.5225', '0.0005', '-0.4808', '0.0057', '-0.2580', '0.0215', '-0.1167', '0.0450', '-0.0231', '0.0636', '-0.0001', '0.0770', '-0.0001', '0.1579', '-0.0003', '0.0917', '-0.0003', '0.1226', '-0.0001', '0.1144', '-0.0003', '0.1003', '-0.0004', '0.1624', '-0.0004', '0.1643', '-0.0002', '0.1183', '-0.0002', '0.1421', '-0.0002', '0.1087', '0.0000', '0.1108', '-0.0004', '0.1135']
# 2026-02-15 22:07:58,244 | INFO     | polynomial_tutorial.train:114 | Epoch [15200/50000] | Loss: 28.987291 | Params: ['2.7877', '-0.3403', '-2.2298', '-0.0002', '-0.0002', '-0.0000', '0.0002', '-0.1783', '0.0000', '-0.4552', '0.0002', '-0.6644', '0.0004', '-0.6856', '0.0004', '-0.5276', '0.0006', '-0.4832', '0.0067', '-0.2568', '0.0233', '-0.1115', '0.0472', '-0.0136', '0.0659', '-0.0002', '0.0792', '-0.0001', '0.1599', '-0.0004', '0.0936', '-0.0001', '0.1242', '-0.0003', '0.1158', '-0.0001', '0.1014', '-0.0004', '0.1634', '-0.0004', '0.1651', '-0.0003', '0.1190', '-0.0001', '0.1426', '0.0000', '0.1092', '-0.0004', '0.1112', '0.0001', '0.1139']
# 2026-02-15 22:07:58,359 | INFO     | polynomial_tutorial.train:114 | Epoch [15600/50000] | Loss: 28.985115 | Params: ['2.7949', '-0.3395', '-2.2529', '-0.0000', '0.0000', '-0.0004', '0.0001', '-0.1725', '0.0005', '-0.4572', '0.0004', '-0.6702', '0.0005', '-0.6922', '0.0004', '-0.5328', '0.0002', '-0.4856', '0.0078', '-0.2556', '0.0252', '-0.1063', '0.0494', '-0.0041', '0.0682', '-0.0002', '0.0814', '-0.0001', '0.1619', '-0.0005', '0.0954', '-0.0005', '0.1257', '-0.0000', '0.1171', '-0.0005', '0.1025', '0.0001', '0.1642', '-0.0004', '0.1658', '-0.0005', '0.1195', '0.0001', '0.1430', '-0.0004', '0.1095', '-0.0003', '0.1114', '-0.0001', '0.1141']
# 2026-02-15 22:07:58,489 | INFO     | polynomial_tutorial.train:114 | Epoch [16000/50000] | Loss: 28.983160 | Params: ['2.8017', '-0.3388', '-2.2749', '-0.0004', '-0.0001', '-0.0000', '-0.0000', '-0.1665', '0.0001', '-0.4592', '0.0003', '-0.6760', '0.0003', '-0.6986', '0.0006', '-0.5378', '0.0006', '-0.4879', '0.0090', '-0.2544', '0.0271', '-0.1010', '0.0516', '-0.0006', '0.0705', '-0.0002', '0.0836', '-0.0001', '0.1639', '0.0000', '0.0971', '-0.0002', '0.1272', '-0.0003', '0.1183', '-0.0002', '0.1035', '0.0000', '0.1650', '-0.0004', '0.1664', '0.0000', '0.1200', '-0.0003', '0.1434', '-0.0001', '0.1097', '-0.0001', '0.1116', '-0.0001', '0.1141']
# 2026-02-15 22:07:58,607 | INFO     | polynomial_tutorial.train:114 | Epoch [16400/50000] | Loss: 28.981499 | Params: ['2.8083', '-0.3378', '-2.2959', '-0.0005', '-0.0001', '0.0000', '0.0004', '-0.1602', '0.0002', '-0.4609', '0.0005', '-0.6814', '0.0003', '-0.7048', '0.0003', '-0.5426', '0.0004', '-0.4900', '0.0102', '-0.2528', '0.0291', '-0.0954', '0.0538', '-0.0004', '0.0727', '-0.0005', '0.0857', '-0.0004', '0.1658', '-0.0004', '0.0988', '-0.0003', '0.1286', '-0.0003', '0.1194', '-0.0003', '0.1044', '-0.0004', '0.1657', '-0.0001', '0.1669', '-0.0004', '0.1203', '0.0001', '0.1436', '-0.0002', '0.1098', '-0.0003', '0.1116', '-0.0000', '0.1141']
# 2026-02-15 22:07:58,723 | INFO     | polynomial_tutorial.train:114 | Epoch [16800/50000] | Loss: 28.979914 | Params: ['2.8145', '-0.3368', '-2.3160', '-0.0004', '-0.0000', '-0.0003', '0.0001', '-0.1537', '0.0000', '-0.4624', '0.0004', '-0.6867', '0.0004', '-0.7108', '0.0001', '-0.5472', '0.0004', '-0.4918', '0.0116', '-0.2511', '0.0311', '-0.0896', '0.0561', '-0.0006', '0.0750', '-0.0000', '0.0878', '-0.0005', '0.1677', '-0.0000', '0.1004', '-0.0003', '0.1300', '-0.0001', '0.1205', '-0.0002', '0.1052', '-0.0000', '0.1663', '-0.0003', '0.1673', '-0.0001', '0.1206', '0.0001', '0.1437', '-0.0001', '0.1099', '-0.0003', '0.1115', '-0.0003', '0.1140']
# 2026-02-15 22:07:58,839 | INFO     | polynomial_tutorial.train:114 | Epoch [17200/50000] | Loss: 28.978312 | Params: ['2.8205', '-0.3358', '-2.3352', '-0.0003', '0.0002', '-0.0000', '0.0004', '-0.1471', '0.0002', '-0.4638', '0.0005', '-0.6918', '0.0002', '-0.7166', '0.0001', '-0.5517', '0.0004', '-0.4935', '0.0129', '-0.2492', '0.0331', '-0.0838', '0.0583', '-0.0000', '0.0772', '-0.0000', '0.0899', '-0.0005', '0.1696', '-0.0002', '0.1020', '-0.0001', '0.1313', '-0.0004', '0.1215', '-0.0000', '0.1060', '-0.0001', '0.1669', '-0.0003', '0.1677', '-0.0003', '0.1208', '-0.0004', '0.1437', '0.0000', '0.1098', '-0.0003', '0.1114', '0.0001', '0.1137']
# 2026-02-15 22:07:58,954 | INFO     | polynomial_tutorial.train:114 | Epoch [17600/50000] | Loss: 28.976904 | Params: ['2.8262', '-0.3349', '-2.3535', '-0.0001', '-0.0002', '-0.0002', '0.0004', '-0.1404', '0.0002', '-0.4650', '0.0003', '-0.6968', '0.0001', '-0.7223', '0.0002', '-0.5560', '0.0006', '-0.4951', '0.0144', '-0.2472', '0.0352', '-0.0778', '0.0606', '-0.0000', '0.0795', '-0.0005', '0.0920', '-0.0004', '0.1714', '-0.0002', '0.1035', '-0.0004', '0.1325', '0.0000', '0.1225', '-0.0003', '0.1067', '-0.0001', '0.1673', '-0.0002', '0.1680', '-0.0003', '0.1208', '-0.0002', '0.1437', '-0.0003', '0.1096', '-0.0001', '0.1111', '0.0000', '0.1134']
# 2026-02-15 22:07:59,070 | INFO     | polynomial_tutorial.train:114 | Epoch [18000/50000] | Loss: 28.975525 | Params: ['2.8316', '-0.3342', '-2.3711', '0.0000', '0.0000', '-0.0003', '0.0004', '-0.1337', '0.0004', '-0.4662', '0.0003', '-0.7018', '0.0002', '-0.7280', '0.0004', '-0.5602', '0.0008', '-0.4966', '0.0158', '-0.2452', '0.0372', '-0.0717', '0.0629', '-0.0005', '0.0817', '-0.0003', '0.0940', '-0.0002', '0.1732', '-0.0001', '0.1050', '0.0000', '0.1337', '-0.0001', '0.1234', '0.0001', '0.1073', '-0.0001', '0.1677', '-0.0001', '0.1681', '-0.0003', '0.1209', '0.0000', '0.1435', '0.0001', '0.1093', '-0.0004', '0.1107', '0.0000', '0.1130']
# 2026-02-15 22:07:59,187 | INFO     | polynomial_tutorial.train:114 | Epoch [18400/50000] | Loss: 28.974270 | Params: ['2.8368', '-0.3335', '-2.3878', '-0.0005', '0.0003', '-0.0005', '0.0001', '-0.1269', '0.0004', '-0.4673', '0.0005', '-0.7067', '0.0005', '-0.7335', '0.0002', '-0.5644', '0.0011', '-0.4980', '0.0174', '-0.2431', '0.0393', '-0.0655', '0.0652', '-0.0003', '0.0839', '-0.0001', '0.0961', '-0.0005', '0.1749', '0.0000', '0.1064', '-0.0002', '0.1348', '-0.0001', '0.1242', '-0.0001', '0.1079', '0.0000', '0.1681', '0.0001', '0.1682', '-0.0003', '0.1208', '-0.0002', '0.1433', '-0.0001', '0.1090', '-0.0001', '0.1103', '0.0000', '0.1125']
# 2026-02-15 22:07:59,303 | INFO     | polynomial_tutorial.train:114 | Epoch [18800/50000] | Loss: 28.973179 | Params: ['2.8417', '-0.3329', '-2.4039', '-0.0003', '-0.0002', '0.0000', '0.0003', '-0.1201', '-0.0000', '-0.4684', '0.0004', '-0.7115', '0.0003', '-0.7391', '0.0000', '-0.5686', '0.0014', '-0.4994', '0.0189', '-0.2409', '0.0415', '-0.0593', '0.0674', '-0.0001', '0.0861', '-0.0004', '0.0980', '-0.0002', '0.1766', '-0.0004', '0.1078', '-0.0003', '0.1359', '-0.0001', '0.1250', '-0.0002', '0.1084', '-0.0004', '0.1683', '-0.0003', '0.1683', '-0.0002', '0.1206', '-0.0005', '0.1430', '-0.0003', '0.1086', '-0.0004', '0.1098', '0.0001', '0.1119']
# 2026-02-15 22:07:59,419 | INFO     | polynomial_tutorial.train:114 | Epoch [19200/50000] | Loss: 28.972052 | Params: ['2.8464', '-0.3325', '-2.4193', '-0.0003', '-0.0001', '-0.0001', '0.0002', '-0.1132', '0.0005', '-0.4695', '0.0004', '-0.7163', '0.0002', '-0.7446', '0.0006', '-0.5727', '0.0018', '-0.5008', '0.0205', '-0.2387', '0.0436', '-0.0531', '0.0697', '-0.0004', '0.0883', '-0.0001', '0.1000', '-0.0005', '0.1783', '-0.0001', '0.1092', '-0.0003', '0.1370', '-0.0001', '0.1258', '-0.0003', '0.1089', '-0.0002', '0.1685', '0.0000', '0.1683', '-0.0000', '0.1204', '-0.0000', '0.1427', '-0.0004', '0.1081', '0.0000', '0.1092', '-0.0003', '0.1112']
# 2026-02-15 22:07:59,535 | INFO     | polynomial_tutorial.train:114 | Epoch [19600/50000] | Loss: 28.970917 | Params: ['2.8509', '-0.3321', '-2.4340', '-0.0002', '-0.0001', '-0.0002', '0.0004', '-0.1063', '0.0001', '-0.4705', '0.0000', '-0.7211', '0.0003', '-0.7500', '0.0006', '-0.5767', '0.0023', '-0.5021', '0.0222', '-0.2364', '0.0457', '-0.0468', '0.0720', '-0.0001', '0.0905', '-0.0003', '0.1020', '-0.0001', '0.1800', '-0.0005', '0.1105', '-0.0004', '0.1380', '-0.0000', '0.1264', '-0.0003', '0.1093', '0.0001', '0.1686', '-0.0003', '0.1682', '-0.0004', '0.1201', '-0.0002', '0.1422', '-0.0004', '0.1075', '-0.0001', '0.1085', '-0.0002', '0.1104']
# 2026-02-15 22:07:59,651 | INFO     | polynomial_tutorial.train:114 | Epoch [20000/50000] | Loss: 28.969891 | Params: ['2.8552', '-0.3318', '-2.4481', '-0.0002', '-0.0002', '-0.0003', '0.0004', '-0.0995', '0.0004', '-0.4715', '0.0004', '-0.7258', '0.0004', '-0.7555', '0.0001', '-0.5808', '0.0029', '-0.5034', '0.0238', '-0.2342', '0.0479', '-0.0405', '0.0743', '-0.0004', '0.0927', '-0.0005', '0.1039', '-0.0003', '0.1816', '-0.0002', '0.1118', '-0.0004', '0.1389', '0.0001', '0.1271', '-0.0003', '0.1096', '-0.0003', '0.1687', '0.0001', '0.1680', '-0.0002', '0.1198', '-0.0003', '0.1417', '0.0001', '0.1069', '-0.0003', '0.1078', '0.0000', '0.1096']
# 2026-02-15 22:07:59,768 | INFO     | polynomial_tutorial.train:114 | Epoch [20400/50000] | Loss: 28.969000 | Params: ['2.8593', '-0.3316', '-2.4616', '-0.0002', '0.0001', '-0.0004', '0.0002', '-0.0926', '0.0005', '-0.4725', '0.0003', '-0.7305', '0.0001', '-0.7609', '0.0003', '-0.5848', '0.0034', '-0.5047', '0.0255', '-0.2318', '0.0501', '-0.0342', '0.0766', '-0.0000', '0.0948', '-0.0000', '0.1058', '-0.0004', '0.1832', '-0.0005', '0.1130', '-0.0004', '0.1398', '-0.0004', '0.1277', '-0.0003', '0.1099', '0.0001', '0.1688', '-0.0002', '0.1678', '0.0000', '0.1194', '-0.0004', '0.1411', '0.0001', '0.1062', '-0.0004', '0.1070', '-0.0004', '0.1087']
# 2026-02-15 22:07:59,883 | INFO     | polynomial_tutorial.train:114 | Epoch [20800/50000] | Loss: 28.967979 | Params: ['2.8632', '-0.3315', '-2.4745', '-0.0002', '0.0002', '-0.0005', '0.0002', '-0.0857', '0.0001', '-0.4734', '0.0004', '-0.7352', '0.0005', '-0.7663', '0.0005', '-0.5888', '0.0041', '-0.5059', '0.0273', '-0.2295', '0.0523', '-0.0278', '0.0789', '-0.0003', '0.0970', '-0.0002', '0.1077', '0.0000', '0.1847', '-0.0001', '0.1143', '-0.0003', '0.1407', '-0.0003', '0.1282', '-0.0003', '0.1101', '-0.0002', '0.1687', '-0.0004', '0.1676', '-0.0003', '0.1189', '0.0001', '0.1405', '0.0001', '0.1054', '0.0001', '0.1061', '-0.0001', '0.1077']
# 2026-02-15 22:08:00,001 | INFO     | polynomial_tutorial.train:114 | Epoch [21200/50000] | Loss: 28.966923 | Params: ['2.8670', '-0.3314', '-2.4869', '-0.0002', '0.0001', '-0.0000', '-0.0001', '-0.0787', '-0.0001', '-0.4744', '0.0001', '-0.7399', '0.0005', '-0.7716', '0.0003', '-0.5927', '0.0047', '-0.5071', '0.0290', '-0.2272', '0.0545', '-0.0215', '0.0811', '-0.0004', '0.0991', '-0.0003', '0.1096', '-0.0001', '0.1863', '-0.0004', '0.1155', '-0.0003', '0.1415', '-0.0001', '0.1287', '-0.0002', '0.1103', '-0.0005', '0.1687', '0.0000', '0.1673', '-0.0001', '0.1184', '0.0001', '0.1398', '-0.0005', '0.1046', '0.0000', '0.1051', '0.0001', '0.1067']
# 2026-02-15 22:08:00,118 | INFO     | polynomial_tutorial.train:114 | Epoch [21600/50000] | Loss: 28.966143 | Params: ['2.8706', '-0.3314', '-2.4987', '-0.0003', '-0.0002', '-0.0001', '-0.0001', '-0.0718', '-0.0000', '-0.4753', '0.0005', '-0.7446', '0.0005', '-0.7770', '0.0001', '-0.5967', '0.0055', '-0.5083', '0.0308', '-0.2248', '0.0567', '-0.0151', '0.0834', '-0.0000', '0.1013', '-0.0004', '0.1114', '-0.0002', '0.1878', '0.0000', '0.1166', '-0.0002', '0.1423', '-0.0005', '0.1292', '-0.0001', '0.1105', '-0.0001', '0.1685', '-0.0001', '0.1669', '-0.0004', '0.1179', '0.0000', '0.1391', '-0.0004', '0.1037', '-0.0000', '0.1042', '-0.0002', '0.1056']
# 2026-02-15 22:08:00,237 | INFO     | polynomial_tutorial.train:114 | Epoch [22000/50000] | Loss: 28.965427 | Params: ['2.8740', '-0.3314', '-2.5101', '-0.0003', '-0.0001', '-0.0003', '0.0001', '-0.0649', '0.0002', '-0.4763', '0.0004', '-0.7492', '0.0006', '-0.7823', '0.0005', '-0.6006', '0.0062', '-0.5095', '0.0326', '-0.2224', '0.0589', '-0.0086', '0.0857', '-0.0002', '0.1034', '-0.0005', '0.1132', '-0.0003', '0.1893', '-0.0002', '0.1177', '-0.0001', '0.1431', '-0.0003', '0.1296', '-0.0000', '0.1106', '-0.0003', '0.1684', '-0.0003', '0.1665', '-0.0001', '0.1173', '-0.0000', '0.1383', '-0.0004', '0.1028', '-0.0001', '0.1031', '0.0000', '0.1045']
# 2026-02-15 22:08:00,353 | INFO     | polynomial_tutorial.train:114 | Epoch [22400/50000] | Loss: 28.964569 | Params: ['2.8772', '-0.3315', '-2.5210', '-0.0004', '-0.0002', '-0.0004', '0.0000', '-0.0580', '-0.0000', '-0.4772', '0.0004', '-0.7539', '0.0001', '-0.7876', '0.0004', '-0.6045', '0.0070', '-0.5106', '0.0344', '-0.2200', '0.0612', '-0.0022', '0.0880', '-0.0003', '0.1055', '-0.0006', '0.1151', '-0.0003', '0.1908', '-0.0004', '0.1188', '0.0000', '0.1438', '-0.0001', '0.1300', '0.0001', '0.1107', '0.0000', '0.1682', '-0.0004', '0.1661', '-0.0003', '0.1166', '-0.0000', '0.1375', '-0.0003', '0.1018', '-0.0001', '0.1020', '-0.0003', '0.1033']
# 2026-02-15 22:08:00,468 | INFO     | polynomial_tutorial.train:114 | Epoch [22800/50000] | Loss: 28.963852 | Params: ['2.8804', '-0.3315', '-2.5315', '-0.0005', '-0.0001', '-0.0004', '0.0001', '-0.0510', '-0.0001', '-0.4780', '0.0005', '-0.7584', '0.0004', '-0.7929', '0.0004', '-0.6084', '0.0079', '-0.5117', '0.0363', '-0.2175', '0.0634', '-0.0005', '0.0902', '-0.0004', '0.1076', '0.0000', '0.1169', '-0.0003', '0.1922', '-0.0005', '0.1199', '-0.0004', '0.1445', '-0.0004', '0.1303', '-0.0004', '0.1107', '-0.0001', '0.1679', '0.0001', '0.1656', '0.0000', '0.1159', '0.0000', '0.1366', '-0.0002', '0.1008', '-0.0001', '0.1009', '0.0001', '0.1021']
# 2026-02-15 22:08:00,584 | INFO     | polynomial_tutorial.train:114 | Epoch [23200/50000] | Loss: 28.963110 | Params: ['2.8834', '-0.3314', '-2.5415', '-0.0003', '-0.0002', '-0.0003', '0.0005', '-0.0438', '0.0000', '-0.4787', '0.0002', '-0.7628', '0.0001', '-0.7979', '0.0004', '-0.6120', '0.0087', '-0.5126', '0.0381', '-0.2148', '0.0657', '-0.0004', '0.0925', '-0.0003', '0.1097', '-0.0004', '0.1186', '-0.0001', '0.1936', '-0.0005', '0.1209', '-0.0000', '0.1452', '0.0000', '0.1307', '-0.0000', '0.1107', '-0.0001', '0.1677', '-0.0004', '0.1650', '-0.0000', '0.1152', '-0.0004', '0.1357', '0.0001', '0.0997', '0.0001', '0.0997', '0.0000', '0.1008']
# 2026-02-15 22:08:00,700 | INFO     | polynomial_tutorial.train:114 | Epoch [23600/50000] | Loss: 28.962513 | Params: ['2.8862', '-0.3312', '-2.5512', '-0.0001', '-0.0001', '0.0000', '0.0004', '-0.0364', '0.0003', '-0.4792', '0.0006', '-0.7670', '0.0006', '-0.8028', '0.0005', '-0.6155', '0.0096', '-0.5134', '0.0400', '-0.2120', '0.0679', '-0.0002', '0.0948', '-0.0000', '0.1117', '-0.0001', '0.1204', '-0.0004', '0.1950', '-0.0003', '0.1220', '-0.0001', '0.1459', '0.0000', '0.1310', '-0.0001', '0.1107', '0.0001', '0.1674', '-0.0002', '0.1645', '0.0001', '0.1144', '-0.0000', '0.1348', '-0.0001', '0.0986', '-0.0002', '0.0985', '0.0001', '0.0995']
# 2026-02-15 22:08:00,817 | INFO     | polynomial_tutorial.train:114 | Epoch [24000/50000] | Loss: 28.962002 | Params: ['2.8890', '-0.3311', '-2.5604', '-0.0004', '-0.0002', '-0.0003', '-0.0001', '-0.0290', '0.0001', '-0.4796', '0.0004', '-0.7711', '0.0004', '-0.8076', '0.0000', '-0.6189', '0.0105', '-0.5140', '0.0419', '-0.2091', '0.0702', '-0.0004', '0.0970', '-0.0003', '0.1138', '-0.0002', '0.1222', '0.0000', '0.1964', '0.0001', '0.1230', '-0.0001', '0.1465', '-0.0005', '0.1312', '-0.0001', '0.1107', '-0.0003', '0.1670', '-0.0004', '0.1639', '-0.0003', '0.1136', '-0.0002', '0.1338', '-0.0001', '0.0975', '-0.0004', '0.0973', '-0.0004', '0.0982']
# 2026-02-15 22:08:00,934 | INFO     | polynomial_tutorial.train:114 | Epoch [24400/50000] | Loss: 28.961361 | Params: ['2.8916', '-0.3310', '-2.5693', '-0.0001', '-0.0001', '-0.0005', '0.0002', '-0.0215', '-0.0000', '-0.4799', '0.0003', '-0.7752', '0.0004', '-0.8123', '0.0002', '-0.6222', '0.0115', '-0.5146', '0.0438', '-0.2061', '0.0724', '-0.0000', '0.0993', '-0.0004', '0.1158', '-0.0003', '0.1239', '-0.0000', '0.1978', '-0.0002', '0.1239', '-0.0001', '0.1471', '-0.0003', '0.1315', '-0.0001', '0.1106', '-0.0005', '0.1666', '-0.0000', '0.1633', '-0.0000', '0.1128', '-0.0002', '0.1328', '-0.0001', '0.0963', '-0.0004', '0.0960', '-0.0001', '0.0968']
# 2026-02-15 22:08:01,049 | INFO     | polynomial_tutorial.train:114 | Epoch [24800/50000] | Loss: 28.960762 | Params: ['2.8941', '-0.3309', '-2.5779', '-0.0004', '0.0003', '-0.0001', '0.0001', '-0.0140', '0.0000', '-0.4802', '0.0004', '-0.7791', '0.0003', '-0.8170', '0.0004', '-0.6254', '0.0124', '-0.5151', '0.0457', '-0.2030', '0.0747', '-0.0001', '0.1016', '-0.0005', '0.1179', '-0.0003', '0.1256', '-0.0000', '0.1991', '-0.0003', '0.1249', '-0.0005', '0.1476', '-0.0000', '0.1317', '-0.0005', '0.1105', '-0.0001', '0.1662', '-0.0001', '0.1626', '-0.0003', '0.1119', '-0.0002', '0.1317', '-0.0000', '0.0951', '-0.0005', '0.0946', '-0.0004', '0.0954']
# 2026-02-15 22:08:01,165 | INFO     | polynomial_tutorial.train:114 | Epoch [25200/50000] | Loss: 28.960253 | Params: ['2.8965', '-0.3309', '-2.5861', '-0.0001', '0.0003', '-0.0003', '0.0002', '-0.0064', '0.0002', '-0.4805', '0.0005', '-0.7831', '0.0004', '-0.8216', '0.0006', '-0.6286', '0.0134', '-0.5155', '0.0476', '-0.1999', '0.0769', '-0.0002', '0.1038', '-0.0005', '0.1199', '-0.0003', '0.1273', '0.0000', '0.2004', '-0.0004', '0.1258', '-0.0003', '0.1482', '-0.0003', '0.1319', '-0.0003', '0.1103', '-0.0002', '0.1658', '-0.0002', '0.1619', '-0.0005', '0.1110', '-0.0001', '0.1306', '0.0001', '0.0939', '-0.0004', '0.0933', '-0.0000', '0.0939']
# 2026-02-15 22:08:01,280 | INFO     | polynomial_tutorial.train:114 | Epoch [25600/50000] | Loss: 28.959835 | Params: ['2.8988', '-0.3310', '-2.5940', '-0.0005', '-0.0001', '-0.0004', '0.0004', '-0.0000', '0.0004', '-0.4807', '0.0000', '-0.7870', '0.0005', '-0.8261', '0.0002', '-0.6318', '0.0144', '-0.5159', '0.0496', '-0.1967', '0.0792', '-0.0002', '0.1061', '-0.0005', '0.1219', '-0.0002', '0.1290', '-0.0005', '0.2018', '-0.0004', '0.1268', '0.0000', '0.1487', '0.0001', '0.1321', '-0.0000', '0.1102', '-0.0002', '0.1654', '-0.0002', '0.1612', '0.0000', '0.1101', '0.0000', '0.1295', '-0.0003', '0.0926', '-0.0003', '0.0919', '-0.0002', '0.0925']
# 2026-02-15 22:08:01,396 | INFO     | polynomial_tutorial.train:114 | Epoch [26000/50000] | Loss: 28.959324 | Params: ['2.9010', '-0.3308', '-2.6015', '-0.0005', '-0.0002', '-0.0003', '0.0002', '-0.0006', '0.0002', '-0.4806', '0.0003', '-0.7906', '0.0000', '-0.8304', '0.0005', '-0.6346', '0.0155', '-0.5160', '0.0515', '-0.1932', '0.0815', '-0.0005', '0.1083', '-0.0002', '0.1240', '-0.0004', '0.1307', '-0.0001', '0.2031', '-0.0002', '0.1277', '-0.0001', '0.1492', '0.0001', '0.1322', '-0.0001', '0.1100', '-0.0001', '0.1649', '0.0001', '0.1605', '0.0001', '0.1091', '-0.0002', '0.1284', '-0.0005', '0.0914', '-0.0000', '0.0905', '-0.0002', '0.0909']
# 2026-02-15 22:08:01,513 | INFO     | polynomial_tutorial.train:114 | Epoch [26400/50000] | Loss: 28.959030 | Params: ['2.9031', '-0.3301', '-2.6088', '-0.0001', '-0.0002', '-0.0004', '0.0001', '-0.0001', '0.0000', '-0.4802', '0.0006', '-0.7939', '0.0002', '-0.8344', '0.0002', '-0.6372', '0.0165', '-0.5159', '0.0535', '-0.1895', '0.0837', '0.0000', '0.1105', '-0.0003', '0.1260', '-0.0004', '0.1324', '-0.0002', '0.2043', '-0.0003', '0.1285', '0.0000', '0.1497', '-0.0003', '0.1323', '-0.0000', '0.1098', '-0.0003', '0.1644', '-0.0001', '0.1597', '-0.0002', '0.1081', '-0.0003', '0.1272', '-0.0004', '0.0900', '-0.0001', '0.0891', '0.0001', '0.0894']
# 2026-02-15 22:08:01,629 | INFO     | polynomial_tutorial.train:114 | Epoch [26800/50000] | Loss: 28.958813 | Params: ['2.9051', '-0.3293', '-2.6159', '-0.0001', '0.0001', '-0.0002', '0.0001', '-0.0001', '-0.0000', '-0.4796', '0.0003', '-0.7970', '0.0004', '-0.8382', '0.0006', '-0.6396', '0.0175', '-0.5155', '0.0554', '-0.1856', '0.0860', '-0.0005', '0.1128', '-0.0002', '0.1280', '-0.0003', '0.1340', '-0.0000', '0.2056', '-0.0003', '0.1294', '-0.0003', '0.1502', '0.0001', '0.1324', '-0.0004', '0.1096', '-0.0004', '0.1639', '-0.0001', '0.1590', '-0.0004', '0.1071', '-0.0002', '0.1260', '-0.0003', '0.0887', '-0.0000', '0.0876', '-0.0002', '0.0879']
# 2026-02-15 22:08:01,745 | INFO     | polynomial_tutorial.train:114 | Epoch [27200/50000] | Loss: 28.958368 | Params: ['2.9070', '-0.3283', '-2.6226', '0.0001', '-0.0001', '0.0000', '0.0003', '-0.0005', '-0.0000', '-0.4788', '0.0002', '-0.7999', '0.0001', '-0.8418', '0.0003', '-0.6419', '0.0186', '-0.5150', '0.0574', '-0.1816', '0.0883', '-0.0003', '0.1150', '-0.0005', '0.1300', '0.0000', '0.1357', '-0.0004', '0.2069', '-0.0002', '0.1303', '-0.0005', '0.1507', '-0.0000', '0.1325', '-0.0000', '0.1093', '-0.0003', '0.1633', '-0.0000', '0.1582', '-0.0004', '0.1061', '0.0000', '0.1248', '0.0000', '0.0873', '-0.0004', '0.0861', '-0.0003', '0.0863']
# 2026-02-15 22:08:01,860 | INFO     | polynomial_tutorial.train:114 | Epoch [27600/50000] | Loss: 28.958147 | Params: ['2.9089', '-0.3274', '-2.6292', '-0.0003', '-0.0000', '-0.0001', '-0.0000', '-0.0001', '0.0001', '-0.4779', '0.0000', '-0.8028', '0.0004', '-0.8453', '0.0001', '-0.6440', '0.0197', '-0.5145', '0.0593', '-0.1775', '0.0905', '-0.0006', '0.1172', '-0.0002', '0.1319', '-0.0002', '0.1373', '0.0000', '0.2081', '0.0000', '0.1311', '0.0000', '0.1511', '-0.0001', '0.1326', '-0.0001', '0.1091', '-0.0002', '0.1628', '-0.0004', '0.1573', '-0.0004', '0.1051', '-0.0003', '0.1236', '-0.0002', '0.0860', '-0.0002', '0.0846', '-0.0003', '0.0847']
# 2026-02-15 22:08:01,976 | INFO     | polynomial_tutorial.train:114 | Epoch [28000/50000] | Loss: 28.957794 | Params: ['2.9107', '-0.3264', '-2.6354', '0.0000', '0.0001', '-0.0003', '0.0004', '-0.0003', '0.0003', '-0.4769', '0.0005', '-0.8055', '0.0001', '-0.8488', '0.0005', '-0.6461', '0.0208', '-0.5138', '0.0613', '-0.1733', '0.0928', '-0.0002', '0.1194', '-0.0004', '0.1339', '-0.0004', '0.1389', '-0.0002', '0.2093', '-0.0003', '0.1319', '-0.0000', '0.1515', '-0.0000', '0.1327', '-0.0002', '0.1088', '-0.0000', '0.1622', '-0.0002', '0.1565', '-0.0003', '0.1040', '0.0001', '0.1224', '-0.0004', '0.0846', '0.0001', '0.0831', '-0.0002', '0.0830']
# ...
# 2026-02-15 22:08:06,040 | INFO     | polynomial_tutorial.train:114 | Epoch [42000/50000] | Loss: 28.949850 | Params: ['2.9446', '-0.3131', '-2.7656', '-0.0000', '0.0000', '-0.0003', '0.0004', '-0.0003', '0.0005', '-0.4297', '0.0000', '-0.8889', '0.0003', '-0.9571', '0.0006', '-0.7068', '0.0584', '-0.4798', '0.1279', '-0.0159', '0.1684', '-0.0005', '0.1926', '-0.0005', '0.1981', '-0.0005', '0.1906', '0.0000', '0.2470', '-0.0002', '0.1552', '0.0000', '0.1610', '-0.0003', '0.1292', '-0.0002', '0.0936', '0.0000', '0.1367', '-0.0002', '0.1220', '-0.0003', '0.0618', '-0.0002', '0.0737', '-0.0003', '0.0307', '-0.0002', '0.0249', '-0.0002', '0.0215']
# 2026-02-15 22:08:06,156 | INFO     | polynomial_tutorial.train:114 | Epoch [42400/50000] | Loss: 28.949608 | Params: ['2.9451', '-0.3129', '-2.7679', '-0.0001', '-0.0002', '0.0000', '0.0004', '-0.0006', '0.0003', '-0.4282', '0.0003', '-0.8911', '0.0001', '-0.9601', '0.0003', '-0.7084', '0.0593', '-0.4788', '0.1296', '-0.0114', '0.1705', '-0.0004', '0.1946', '-0.0004', '0.1998', '-0.0004', '0.1920', '-0.0005', '0.2479', '-0.0003', '0.1558', '-0.0004', '0.1611', '-0.0000', '0.1290', '-0.0001', '0.0931', '-0.0002', '0.1359', '-0.0004', '0.1210', '-0.0000', '0.0606', '-0.0003', '0.0723', '-0.0003', '0.0291', '-0.0004', '0.0233', '-0.0001', '0.0198']
# 2026-02-15 22:08:06,278 | INFO     | polynomial_tutorial.train:114 | Epoch [42800/50000] | Loss: 28.949347 | Params: ['2.9456', '-0.3127', '-2.7700', '-0.0002', '0.0001', '-0.0002', '0.0005', '-0.0002', '0.0000', '-0.4267', '0.0000', '-0.8934', '0.0006', '-0.9631', '0.0001', '-0.7101', '0.0603', '-0.4777', '0.1314', '-0.0068', '0.1725', '-0.0003', '0.1965', '-0.0003', '0.2015', '-0.0003', '0.1933', '-0.0005', '0.2489', '-0.0004', '0.1563', '-0.0003', '0.1613', '-0.0004', '0.1288', '-0.0000', '0.0926', '-0.0005', '0.1351', '-0.0000', '0.1199', '-0.0004', '0.0594', '-0.0004', '0.0709', '-0.0004', '0.0276', '0.0001', '0.0216', '0.0001', '0.0180']
# 2026-02-15 22:08:06,393 | INFO     | polynomial_tutorial.train:114 | Epoch [43200/50000] | Loss: 28.949097 | Params: ['2.9461', '-0.3125', '-2.7722', '-0.0003', '-0.0002', '-0.0004', '-0.0001', '-0.0005', '0.0004', '-0.4252', '0.0003', '-0.8957', '0.0004', '-0.9661', '0.0004', '-0.7118', '0.0612', '-0.4767', '0.1331', '-0.0023', '0.1745', '-0.0002', '0.1985', '-0.0003', '0.2032', '-0.0002', '0.1947', '-0.0004', '0.2499', '0.0000', '0.1569', '-0.0001', '0.1615', '-0.0002', '0.1287', '0.0000', '0.0921', '-0.0001', '0.1343', '-0.0002', '0.1189', '-0.0002', '0.0581', '0.0000', '0.0695', '0.0001', '0.0260', '-0.0001', '0.0199', '-0.0004', '0.0163']
# 2026-02-15 22:08:06,508 | INFO     | polynomial_tutorial.train:114 | Epoch [43600/50000] | Loss: 28.948956 | Params: ['2.9466', '-0.3123', '-2.7743', '-0.0003', '0.0002', '-0.0000', '-0.0000', '-0.0001', '0.0002', '-0.4237', '0.0000', '-0.8979', '0.0002', '-0.9691', '0.0002', '-0.7134', '0.0621', '-0.4757', '0.1349', '-0.0002', '0.1765', '-0.0001', '0.2004', '-0.0002', '0.2049', '-0.0001', '0.1960', '-0.0004', '0.2508', '-0.0001', '0.1575', '0.0000', '0.1617', '0.0000', '0.1285', '-0.0005', '0.0916', '-0.0004', '0.1335', '-0.0004', '0.1179', '0.0000', '0.0569', '-0.0001', '0.0681', '0.0001', '0.0245', '-0.0003', '0.0183', '-0.0003', '0.0146']
# 2026-02-15 22:08:06,623 | INFO     | polynomial_tutorial.train:114 | Epoch [44000/50000] | Loss: 28.948811 | Params: ['2.9470', '-0.3120', '-2.7764', '-0.0002', '-0.0000', '-0.0001', '0.0000', '-0.0001', '0.0005', '-0.4220', '0.0003', '-0.9000', '0.0000', '-0.9719', '0.0005', '-0.7149', '0.0631', '-0.4745', '0.1366', '-0.0003', '0.1785', '-0.0004', '0.2024', '0.0000', '0.2066', '-0.0004', '0.1974', '-0.0002', '0.2518', '-0.0000', '0.1580', '-0.0003', '0.1619', '-0.0002', '0.1283', '-0.0003', '0.0911', '0.0001', '0.1328', '0.0001', '0.1169', '-0.0002', '0.0557', '-0.0001', '0.0667', '0.0001', '0.0229', '-0.0004', '0.0166', '-0.0001', '0.0128']
# 2026-02-15 22:08:06,737 | INFO     | polynomial_tutorial.train:114 | Epoch [44400/50000] | Loss: 28.948706 | Params: ['2.9475', '-0.3115', '-2.7784', '0.0001', '-0.0002', '0.0000', '0.0001', '-0.0001', '0.0003', '-0.4202', '0.0005', '-0.9019', '0.0004', '-0.9746', '0.0002', '-0.7163', '0.0639', '-0.4732', '0.1383', '-0.0003', '0.1805', '-0.0001', '0.2043', '-0.0003', '0.2083', '-0.0001', '0.1987', '-0.0005', '0.2527', '-0.0005', '0.1586', '-0.0005', '0.1621', '-0.0004', '0.1281', '0.0000', '0.0906', '0.0000', '0.1320', '0.0001', '0.1159', '-0.0004', '0.0545', '-0.0000', '0.0653', '-0.0004', '0.0214', '-0.0004', '0.0150', '-0.0003', '0.0111']
# 2026-02-15 22:08:06,854 | INFO     | polynomial_tutorial.train:114 | Epoch [44800/50000] | Loss: 28.948566 | Params: ['2.9479', '-0.3110', '-2.7804', '-0.0002', '0.0002', '-0.0004', '0.0001', '-0.0005', '0.0000', '-0.4182', '0.0002', '-0.9038', '0.0002', '-0.9772', '0.0005', '-0.7175', '0.0648', '-0.4718', '0.1400', '-0.0002', '0.1825', '-0.0002', '0.2062', '-0.0004', '0.2099', '-0.0003', '0.2000', '-0.0001', '0.2537', '-0.0003', '0.1591', '-0.0000', '0.1622', '-0.0004', '0.1280', '-0.0002', '0.0901', '0.0001', '0.1312', '-0.0005', '0.1148', '-0.0005', '0.0532', '-0.0005', '0.0639', '-0.0001', '0.0199', '-0.0003', '0.0133', '0.0001', '0.0094']
# 2026-02-15 22:08:06,969 | INFO     | polynomial_tutorial.train:114 | Epoch [45200/50000] | Loss: 28.948534 | Params: ['2.9484', '-0.3105', '-2.7824', '-0.0004', '0.0000', '-0.0001', '0.0002', '-0.0003', '0.0003', '-0.4163', '0.0004', '-0.9056', '-0.0000', '-0.9797', '0.0002', '-0.7188', '0.0657', '-0.4703', '0.1417', '-0.0000', '0.1844', '-0.0003', '0.2081', '0.0000', '0.2116', '-0.0004', '0.2014', '-0.0003', '0.2546', '-0.0000', '0.1597', '-0.0001', '0.1624', '-0.0005', '0.1278', '-0.0003', '0.0896', '-0.0004', '0.1304', '-0.0003', '0.1138', '0.0001', '0.0520', '-0.0002', '0.0625', '-0.0005', '0.0183', '-0.0001', '0.0117', '-0.0001', '0.0076']
# 2026-02-15 22:08:07,086 | INFO     | polynomial_tutorial.train:114 | Epoch [45600/50000] | Loss: 28.948351 | Params: ['2.9488', '-0.3100', '-2.7843', '0.0000', '-0.0002', '-0.0004', '0.0003', '0.0000', '0.0001', '-0.4142', '0.0001', '-0.9073', '0.0004', '-0.9822', '0.0005', '-0.7199', '0.0666', '-0.4688', '0.1434', '-0.0004', '0.1864', '-0.0004', '0.2100', '-0.0000', '0.2133', '-0.0005', '0.2027', '-0.0004', '0.2556', '-0.0003', '0.1602', '-0.0001', '0.1626', '-0.0004', '0.1276', '-0.0004', '0.0892', '-0.0003', '0.1297', '-0.0001', '0.1128', '-0.0005', '0.0508', '0.0000', '0.0611', '-0.0001', '0.0168', '0.0001', '0.0101', '-0.0001', '0.0059']
# 2026-02-15 22:08:07,209 | INFO     | polynomial_tutorial.train:114 | Epoch [46000/50000] | Loss: 28.948273 | Params: ['2.9492', '-0.3096', '-2.7862', '-0.0002', '0.0003', '-0.0001', '0.0003', '-0.0003', '0.0004', '-0.4121', '0.0003', '-0.9090', '0.0001', '-0.9847', '0.0001', '-0.7210', '0.0674', '-0.4673', '0.1451', '-0.0002', '0.1883', '-0.0003', '0.2119', '-0.0001', '0.2149', '-0.0005', '0.2040', '-0.0004', '0.2565', '0.0001', '0.1608', '-0.0001', '0.1628', '-0.0003', '0.1274', '-0.0005', '0.0887', '-0.0001', '0.1289', '-0.0005', '0.1118', '-0.0004', '0.0496', '-0.0003', '0.0598', '-0.0004', '0.0153', '-0.0003', '0.0084', '-0.0002', '0.0042']
# 2026-02-15 22:08:07,326 | INFO     | polynomial_tutorial.train:114 | Epoch [46400/50000] | Loss: 28.948147 | Params: ['2.9496', '-0.3091', '-2.7881', '-0.0003', '0.0001', '-0.0004', '0.0004', '-0.0005', '0.0001', '-0.4100', '0.0005', '-0.9107', '0.0004', '-0.9871', '0.0004', '-0.7221', '0.0683', '-0.4657', '0.1468', '-0.0005', '0.1903', '-0.0003', '0.2138', '-0.0001', '0.2166', '-0.0004', '0.2053', '-0.0004', '0.2574', '-0.0001', '0.1613', '-0.0000', '0.1629', '-0.0002', '0.1273', '-0.0005', '0.0882', '-0.0005', '0.1281', '-0.0002', '0.1108', '-0.0003', '0.0484', '0.0001', '0.0584', '0.0000', '0.0138', '0.0000', '0.0068', '-0.0002', '0.0025']
# 2026-02-15 22:08:07,441 | INFO     | polynomial_tutorial.train:114 | Epoch [46800/50000] | Loss: 28.947973 | Params: ['2.9500', '-0.3087', '-2.7899', '-0.0005', '-0.0000', '0.0000', '0.0004', '-0.0001', '0.0004', '-0.4079', '0.0001', '-0.9123', '0.0002', '-0.9894', '0.0000', '-0.7231', '0.0691', '-0.4640', '0.1485', '-0.0002', '0.1922', '-0.0002', '0.2157', '-0.0000', '0.2182', '-0.0004', '0.2066', '-0.0004', '0.2584', '-0.0003', '0.1619', '0.0001', '0.1631', '-0.0000', '0.1271', '-0.0005', '0.0877', '-0.0002', '0.1274', '0.0001', '0.1098', '-0.0001', '0.0472', '-0.0001', '0.0570', '-0.0001', '0.0123', '-0.0003', '0.0052', '-0.0002', '0.0008']
# 2026-02-15 22:08:07,558 | INFO     | polynomial_tutorial.train:114 | Epoch [47200/50000] | Loss: 28.947882 | Params: ['2.9504', '-0.3084', '-2.7917', '-0.0001', '-0.0002', '-0.0002', '0.0004', '-0.0003', '0.0000', '-0.4057', '0.0003', '-0.9139', '0.0005', '-0.9918', '0.0002', '-0.7242', '0.0699', '-0.4624', '0.1501', '-0.0004', '0.1941', '-0.0001', '0.2175', '-0.0005', '0.2198', '-0.0003', '0.2079', '-0.0004', '0.2593', '-0.0004', '0.1624', '-0.0004', '0.1633', '-0.0005', '0.1269', '-0.0004', '0.0872', '0.0001', '0.1266', '-0.0002', '0.1088', '0.0000', '0.0460', '-0.0003', '0.0556', '-0.0003', '0.0108', '0.0001', '0.0036', '-0.0001', '0.0003']
# 2026-02-15 22:08:07,674 | INFO     | polynomial_tutorial.train:114 | Epoch [47600/50000] | Loss: 28.947765 | Params: ['2.9507', '-0.3081', '-2.7936', '-0.0002', '0.0003', '-0.0004', '0.0004', '-0.0005', '0.0003', '-0.4035', '0.0004', '-0.9154', '0.0001', '-0.9941', '0.0004', '-0.7251', '0.0707', '-0.4607', '0.1517', '-0.0000', '0.1960', '-0.0006', '0.2193', '-0.0004', '0.2214', '-0.0002', '0.2092', '-0.0003', '0.2602', '0.0001', '0.1629', '-0.0003', '0.1634', '-0.0002', '0.1267', '-0.0004', '0.0867', '-0.0002', '0.1258', '-0.0004', '0.1077', '-0.0004', '0.0447', '0.0001', '0.0542', '-0.0004', '0.0092', '-0.0002', '0.0019', '-0.0000', '0.0004']
# 2026-02-15 22:08:07,790 | INFO     | polynomial_tutorial.train:114 | Epoch [48000/50000] | Loss: 28.947609 | Params: ['2.9511', '-0.3078', '-2.7954', '-0.0004', '0.0001', '-0.0000', '0.0004', '-0.0001', '0.0005', '-0.4013', '0.0005', '-0.9170', '0.0003', '-0.9964', '0.0005', '-0.7261', '0.0714', '-0.4590', '0.1533', '-0.0002', '0.1978', '-0.0004', '0.2211', '-0.0003', '0.2230', '-0.0001', '0.2104', '-0.0002', '0.2610', '-0.0000', '0.1634', '-0.0001', '0.1635', '-0.0000', '0.1264', '-0.0003', '0.0861', '-0.0005', '0.1250', '-0.0001', '0.1067', '-0.0002', '0.0435', '-0.0000', '0.0528', '0.0001', '0.0076', '-0.0004', '0.0003', '0.0001', '0.0004']
# 2026-02-15 22:08:07,906 | INFO     | polynomial_tutorial.train:114 | Epoch [48400/50000] | Loss: 28.947485 | Params: ['2.9514', '-0.3075', '-2.7972', '0.0000', '-0.0001', '-0.0002', '0.0003', '-0.0002', '0.0000', '-0.3991', '0.0005', '-0.9185', '0.0005', '-0.9986', '0.0000', '-0.7271', '0.0721', '-0.4572', '0.1548', '-0.0004', '0.1996', '-0.0002', '0.2229', '-0.0002', '0.2245', '-0.0005', '0.2116', '-0.0001', '0.2618', '-0.0001', '0.1638', '-0.0005', '0.1636', '-0.0004', '0.1262', '-0.0002', '0.0855', '-0.0001', '0.1241', '-0.0003', '0.1056', '0.0001', '0.0422', '-0.0002', '0.0513', '0.0000', '0.0061', '0.0000', '0.0004', '-0.0004', '0.0004']
# 2026-02-15 22:08:08,022 | INFO     | polynomial_tutorial.train:114 | Epoch [48800/50000] | Loss: 28.947458 | Params: ['2.9518', '-0.3073', '-2.7989', '-0.0001', '0.0003', '-0.0004', '0.0002', '-0.0004', '0.0002', '-0.3969', '0.0005', '-0.9200', '0.0001', '-1.0009', '0.0001', '-0.7280', '0.0728', '-0.4555', '0.1563', '-0.0005', '0.2014', '-0.0000', '0.2246', '-0.0000', '0.2260', '-0.0003', '0.2127', '-0.0000', '0.2626', '-0.0001', '0.1642', '-0.0003', '0.1636', '-0.0001', '0.1258', '-0.0000', '0.0849', '-0.0003', '0.1232', '-0.0005', '0.1045', '-0.0003', '0.0408', '-0.0003', '0.0499', '-0.0000', '0.0044', '-0.0002', '0.0004', '-0.0003', '0.0004']
# 2026-02-15 22:08:08,139 | INFO     | polynomial_tutorial.train:114 | Epoch [49200/50000] | Loss: 28.947392 | Params: ['2.9521', '-0.3071', '-2.8007', '-0.0003', '0.0001', '0.0000', '0.0001', '-0.0005', '0.0003', '-0.3946', '0.0005', '-0.9215', '0.0002', '-1.0032', '0.0001', '-0.7289', '0.0734', '-0.4537', '0.1577', '-0.0001', '0.2031', '-0.0004', '0.2263', '-0.0004', '0.2274', '-0.0001', '0.2139', '-0.0005', '0.2634', '-0.0002', '0.1646', '-0.0001', '0.1636', '-0.0004', '0.1255', '-0.0005', '0.0843', '0.0001', '0.1223', '-0.0000', '0.1033', '-0.0000', '0.0395', '-0.0004', '0.0483', '-0.0000', '0.0028', '-0.0003', '0.0005', '-0.0001', '0.0004']
# 2026-02-15 22:08:08,255 | INFO     | polynomial_tutorial.train:114 | Epoch [49600/50000] | Loss: 28.947176 | Params: ['2.9525', '-0.3070', '-2.8024', '-0.0005', '-0.0001', '-0.0001', '0.0000', '-0.0000', '0.0003', '-0.3924', '0.0005', '-0.9230', '0.0003', '-1.0054', '0.0001', '-0.7298', '0.0740', '-0.4520', '0.1591', '-0.0002', '0.2048', '-0.0002', '0.2280', '-0.0003', '0.2289', '-0.0005', '0.2150', '-0.0003', '0.2641', '-0.0002', '0.1650', '-0.0004', '0.1636', '-0.0001', '0.1252', '-0.0003', '0.0836', '-0.0001', '0.1214', '-0.0002', '0.1022', '-0.0004', '0.0381', '-0.0004', '0.0468', '-0.0001', '0.0011', '0.0001', '0.0005', '0.0000', '0.0004']
# 2026-02-15 22:08:08,372 | INFO     | polynomial_tutorial.train:114 | Epoch [50000/50000] | Loss: 28.947071 | Params: ['2.9529', '-0.3068', '-2.8041', '-0.0001', '0.0003', '-0.0003', '-0.0001', '-0.0001', '0.0004', '-0.3901', '0.0004', '-0.9245', '0.0003', '-1.0076', '0.0001', '-0.7307', '0.0746', '-0.4502', '0.1606', '-0.0003', '0.2065', '-0.0006', '0.2296', '-0.0001', '0.2303', '-0.0003', '0.2161', '-0.0001', '0.2648', '-0.0002', '0.1653', '-0.0002', '0.1636', '-0.0004', '0.1248', '-0.0002', '0.0829', '-0.0003', '0.1204', '-0.0003', '0.1010', '-0.0001', '0.0368', '0.0001', '0.0453', '-0.0001', '0.0001', '-0.0000', '0.0006', '-0.0004', '0.0003']
# 2026-02-15 22:08:08,372 | INFO     | polynomial_tutorial.train:120 | ============================================================
# 2026-02-15 22:08:08,373 | INFO     | polynomial_tutorial.train:121 | Training completed!
# 2026-02-15 22:08:08,373 | INFO     | polynomial_tutorial.train:123 | Final parameters: [2.9528510570526123, -0.30680298805236816, -2.804095506668091, -8.273656567325816e-05, 0.000274665275355801, -0.00031093391589820385, -9.478238644078374e-05, -0.00013395756832323968, 0.0004189645405858755, -0.3900856077671051, 0.00044979594531469047, -0.9245038032531738, 0.00032819778425619006, -1.0076017379760742, 9.06690547708422e-05, -0.7306921482086182, 0.07455826550722122, -0.4501737654209137, 0.1605515331029892, -0.00033493575756438076, 0.2065088450908661, -0.0005718853208236396, 0.2296033799648285, -5.0554837798699737e-05, 0.23029725253582, -0.00032655999530106783, 0.21607783436775208, -0.00014631389058195055, 0.26483428478240967, -0.00020416030019987375, 0.16529901325702667, -0.00018609069229569286, 0.16356366872787476, -0.0003879545256495476, 0.12480561435222626, -0.0001672704383963719, 0.08293765038251877, -0.0003146182280033827, 0.12044628709554672, -0.0003210229624528438, 0.10097919404506683, -5.8121164329349995e-05, 0.03676486015319824, 9.268140274798498e-05, 0.04529233276844025, -8.499447721987963e-05, 7.408507372019812e-05, -7.569955414510332e-06, 0.0005708921235054731, -0.00039054403896443546, 0.00031502742785960436]
# 2026-02-15 22:08:08,373 | INFO     | polynomial_tutorial.train:124 | Final loss: 28.947071
# 2026-02-15 22:08:08,373 | INFO     | polynomial_tutorial.train:125 | ============================================================
#
# ✓ Training completed!
#   Final loss: 28.947071

# %% [markdown]
# ---
#
# ## Part 7: Evaluation
#
# ### Model Performance

# %%
logger.info("\n[STEP 4] Evaluating results...")

fitted_params = trained_model.get_parameters()

if use_normalization:
    logger.info("\n⚠️  Note: Coefficients are for NORMALIZED features")
    logger.info("Cannot directly compare to true coefficients (different scales)")

print(f"\nTrue coefficients (original scale):   {coeffs_true}")
print(f"Fitted coefficients (working scale):  {[f'{p:.4f}' for p in fitted_params]}")

# Compute metrics
metrics = evaluate_model(trained_model, x_t, y_t)
print(f"\nFinal Metrics:")
print(f"  MSE:  {metrics['mse']:.6f}")
print(f"  RMSE: {metrics['rmse']:.6f}")
print(f"\nInterpretation:")
print(f"  Noise level (σ): {noise_std}")
print(f"  RMSE ≈ σ? {abs(metrics['rmse'] - noise_std) < 0.1} (good fit if True)")
# Out:
# 2026-02-15 22:08:08,379 | INFO     | __main__:1 |
# [STEP 4] Evaluating results...
# 2026-02-15 22:08:08,380 | INFO     | __main__:6 |
# ⚠️  Note: Coefficients are for NORMALIZED features
# 2026-02-15 22:08:08,380 | INFO     | __main__:7 | Cannot directly compare to true coefficients (different scales)
#
# True coefficients (original scale):   [1.5, 0.4, 0.07, -0.02, 0.0005]
# Fitted coefficients (working scale):  ['2.9529', '-0.3068', '-2.8041', '-0.0001', '0.0003', '-0.0003', '-0.0001', '-0.0001', '0.0004', '-0.3901', '0.0004', '-0.9245', '0.0003', '-1.0076', '0.0001', '-0.7307', '0.0746', '-0.4502', '0.1606', '-0.0003', '0.2065', '-0.0006', '0.2296', '-0.0001', '0.2303', '-0.0003', '0.2161', '-0.0001', '0.2648', '-0.0002', '0.1653', '-0.0002', '0.1636', '-0.0004', '0.1248', '-0.0002', '0.0829', '-0.0003', '0.1204', '-0.0003', '0.1010', '-0.0001', '0.0368', '0.0001', '0.0453', '-0.0001', '0.0001', '-0.0000', '0.0006', '-0.0004', '0.0003']
#
# Final Metrics:
#   MSE:  25.408287
#   RMSE: 5.040663
#
# Interpretation:
#   Noise level (σ): 5
#   RMSE ≈ σ? True (good fit if True)

# %% [markdown]
# ---
#
# ## Part 8: Visualization - Parameter Evolution
#
# ### How Parameters Converge During Training
#
# Watching parameters converge helps understand:
# - Which coefficients are important (converge to non-zero)
# - Which are less important (converge near zero)
# - Convergence speed differences

# %%
def plot_parameter_evolution(training_history, coeffs_true, model):
    """Visualize parameter convergence."""
    param_history = training_history['params']
    num_epochs = len(param_history)
    
    # Extract parameter array
    param_array = np.array([epoch_params[0].detach().cpu().numpy() 
                            for epoch_params in param_history])
    num_params = param_array.shape[1]
    
    # Create subplots
    fig, axes = plt.subplots(1, num_params, figsize=(5 * num_params, 4))
    if num_params == 1:
        axes = [axes]
    
    epochs = np.arange(num_epochs)
    
    for i in range(num_params):
        ax = axes[i]
        
        # Plot evolution
        ax.plot(epochs, param_array[:, i], 'b-', linewidth=2, 
                label=f'Estimated a_{i}')
        
        # Plot true value if available (and not normalized)
        if i < len(coeffs_true) and not use_normalization:
            ax.axhline(y=coeffs_true[i], color='g', linestyle='--', 
                      linewidth=2, label=f'True a_{i} = {coeffs_true[i]:.3f}')
        
        ax.set_xlabel('Epoch', fontsize=12)
        ax.set_ylabel(f'Coefficient a_{i}', fontsize=12)
        ax.set_title(f'Parameter a_{i} Evolution', fontsize=14)
        ax.legend()
        ax.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()


print("\n[VISUALIZATION 1] Parameter Evolution")
plot_parameter_evolution(training_history, coeffs_true, trained_model)
# Out:
# [VISUALIZATION 1] Parameter Evolution

# %% [markdown]
# ---
#
# ## Part 9: Visualization - Fitted Curve
#
# ### Comparing Model Predictions to True Function

# %%
def plot_results(x_t, y_t, model, training_history, coeffs_true, 
                 data_poly_order, normalizer=None):
    """Visualize fitted curve and loss."""
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    
    # Denormalize for display if needed
    if normalizer is not None:
        x_display = normalizer.inverse_transform(x_t).detach().numpy()
        # Dense points for smooth curve
        x_dense_original = torch.linspace(x_display.min(), x_display.max(), 200)
        x_dense_norm = normalizer.transform(x_dense_original)
        
        with torch.no_grad():
            y_pred_dense = model(x_dense_norm).numpy()
        
        # True function
        y_true_dense = torch.zeros_like(x_dense_original)
        for i, coeff in enumerate(coeffs_true):
            y_true_dense += coeff * (x_dense_original ** i)
        
        x_plot = x_dense_original.numpy()
        y_pred_plot = y_pred_dense
        y_true_plot = y_true_dense.numpy()
    else:
        x_display = x_t.detach().numpy()
        with torch.no_grad():
            y_pred_plot = model(x_t).numpy()
        x_plot = x_display
        y_true_plot = torch.zeros_like(x_t)
        for i, coeff in enumerate(coeffs_true):
            y_true_plot += coeff * (x_t ** i)
        y_true_plot = y_true_plot.numpy()
    
    y_np = y_t.detach().numpy()
    
    # Plot 1: Fitted curve
    axes[0].scatter(x_display, y_np, alpha=0.5, s=30, c='blue', label='Data')
    axes[0].plot(x_plot, y_pred_plot, 'r-', linewidth=2.5, 
                 label=f'Fitted (order={model.order})')
    axes[0].plot(x_plot, y_true_plot, 'g--', linewidth=2, 
                 label=f'True (order={data_poly_order})')
    
    # Scenario title
    if model.order < data_poly_order:
        title = "UNDERFITTING (High Bias)"
    elif model.order == data_poly_order:
        title = "GOOD FIT (Balanced)"
    else:
        title = "POTENTIAL OVERFITTING (High Variance)"
    
    axes[0].set_xlabel('x', fontsize=12)
    axes[0].set_ylabel('y', fontsize=12)
    axes[0].set_title(f'Polynomial Regression: {title}', fontsize=14, fontweight='bold')
    axes[0].legend()
    axes[0].grid(True, alpha=0.3)
    
    # Plot 2: Loss curve
    loss_history = training_history['loss']
    axes[1].plot(loss_history, linewidth=2, color='darkblue')
    axes[1].set_xlabel('Epoch', fontsize=12)
    axes[1].set_ylabel('MSE', fontsize=12)
    axes[1].set_title('Training Loss', fontsize=14)
    axes[1].set_yscale('log')
    axes[1].grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()


print("\n[VISUALIZATION 2] Fitted Curve vs True Function")
plot_results(x_t, y_t, trained_model, training_history, 
             coeffs_true, data_poly_order, normalizer=normalizer)
# Out:
# [VISUALIZATION 2] Fitted Curve vs True Function

# %% [markdown]
# ---
#
# ## Part 10: Understanding the Results
#
# ### Interpreting the Bias-Variance Scenario

# %%
print("="*70)
print(" BIAS-VARIANCE TRADEOFF SUMMARY")
print("="*70)
print(f"\nData Order:       {data_poly_order}")
print(f"Regressor Order:  {regressor_poly_order}")
print(f"Final MSE:        {training_history['loss'][-1]:.6f}")
print(f"RMSE:             {metrics['rmse']:.6f}")
print(f"Noise level (σ):  {noise_std}")

print("\nINTERPRETATION:")

if regressor_poly_order < data_poly_order:
    print("""
🔴 UNDERFITTING (High Bias, Low Variance)
- Model is too simple to capture the true function
- Cannot fit the training data well
- Both training and test error will be high
- Bias dominates the error

Solution: Increase model complexity (higher polynomial order)
""")
elif regressor_poly_order == data_poly_order:
    print("""
🟢 GOOD FIT (Balanced Bias-Variance)
- Model complexity matches data complexity
- Can fit the training data well
- Generalizes well to unseen data
- Optimal tradeoff point

This is the ideal scenario!
""")
else:
    print("""
🟡 OVERFITTING RISK (Low Bias, High Variance)
- Model is too complex for the data
- Fits training data very well (even noise)
- May generalize poorly to new data
- Variance dominates the error

Solution: Reduce model complexity or add regularization
""")

print("="*70)
# Out:
# ======================================================================
#  BIAS-VARIANCE TRADEOFF SUMMARY
# ======================================================================
#
# Data Order:       4
# Regressor Order:  50
# Final MSE:        28.947071
# RMSE:             5.040663
# Noise level (σ):  5
#
# INTERPRETATION:
#
# 🟡 OVERFITTING RISK (Low Bias, High Variance)
# - Model is too complex for the data
# - Fits training data very well (even noise)
# - May generalize poorly to new data
# - Variance dominates the error
#
# Solution: Reduce model complexity or add regularization
#
# ======================================================================

# %% [markdown]
# ---
#
# ## Part 11: Experiments to Try
#
# ### Experiment 1: Underfitting
#
# Try fitting a **linear model** (order 1) to **cubic data** (order 3):

# %%
# Uncomment and run to try underfitting
# data_poly_order = 3
# regressor_poly_order = 1  # Too simple!
# coeffs_true = [1.0, 0.5, -0.3, 0.1]

# Then re-run cells from Part 3 onward

# %% [markdown]
# ### Experiment 2: Overfitting
#
# Try fitting a **6th order** model to **quadratic data** (order 2):

# %%
# Uncomment and run to try overfitting
# data_poly_order = 2
# regressor_poly_order = 6  # Too complex!
# coeffs_true = [1.0, 0.5, -0.3]

# Then re-run cells from Part 3 onward

# %% [markdown]
# ### Experiment 3: Noise Sensitivity
#
# How does noise affect overfitting?

# %%
# Try different noise levels
noise_levels = [0.1, 0.5, 1.0, 2.0]

# Experiment: For each noise level, train overfitted model
# Question: How does noise affect the bias-variance tradeoff?

# %% [markdown]
# ---
#
# ## Part 12: Key Takeaways
#
# ### What You've Learned
#
# 1. **Bias-Variance Tradeoff:**
#    - Model complexity must match data complexity
#    - Too simple → high bias (underfitting)
#    - Too complex → high variance (overfitting)
#    - Just right → balanced (good generalization)
#
# 2. **Feature Normalization:**
#    - Critical for polynomial orders > 2
#    - Prevents numerical instability (NaN values)
#    - Normalize **before** computing polynomial features
#    - Denormalize for interpretable plots
#
# 3. **PyTorch Fundamentals:**
#    - Creating custom `nn.Module` classes
#    - Training loops with autograd
#    - Parameter tracking and visualization
#    - Professional logging practices
#
# 4. **The Goal is NOT Minimum Training Loss!**
#    - Lowest training loss can indicate overfitting
#    - Goal: Build models that **generalize to new data**
#    - RMSE ≈ noise level σ indicates good fit
#
# ### Next Steps
#
# - Try different polynomial orders
# - Experiment with noise levels
# - Implement cross-validation for model selection
# - Add L2 regularization (Ridge regression)
# - Move to Tutorial 2: Neural Networks

# %% [markdown]
# ---
#
# ## Congratulations! 🎉
#
# You've completed Tutorial 1 and learned:
# - ✅ Polynomial regression with PyTorch
# - ✅ The bias-variance tradeoff
# - ✅ Feature normalization for numerical stability
# - ✅ Professional ML coding practices
#
# **Ready for more?** Proceed to Tutorial 2: Perceptron to Deep Neural Networks!
